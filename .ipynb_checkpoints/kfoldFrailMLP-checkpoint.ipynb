# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D, UpSampling1D
from keras.optimizers import Adam, RMSprop, SGD
from sklearn.cross_validation import KFold
import matplotlib.cm as cm
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
import scipy.io
# Out:
# Using TensorFlow backend.
# /home/nikos/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Setting the random seeds
random.seed(1)
np.random.seed(1337)

# %%
def load_data(filepath):

# Description: This function is responsible for loading our data.
# Args in: filepath - the path of the .mat file containing the data
# Returns: inputs - the data, labels - the labels corresponding to the data, 
#            patients - the patients corresponding to the data

    mat = scipy.io.loadmat(filepath)
    inputs_train_folds = mat['X_train_cell']
    labels_train_folds = mat['Y_train_cell']
    patients_train_folds = mat['patientID_train_cell']
    
    inputs_val_folds = mat['X_val_cell']
    labels_val_folds = mat['Y_val_cell']
    patients_val_folds = mat['patientID_val_cell']

    return inputs_train_folds, labels_train_folds, patients_train_folds, inputs_val_folds, labels_val_folds, patients_val_folds

# %%
inputs_train_folds, labels_train_folds, patients_train_folds, inputs_val_folds, labels_val_folds, patients_val_folds = load_data('/home/nikos/Desktop/DeepFrailtyPrediction/FS_Train_TestSets.mat')

# %%
def get_train_test_per_fold(inputs_train_folds, labels_train_folds, patients_train_folds, 
                            inputs_val_folds, labels_val_folds, patients_val_folds, fold_num):

    # Description: This function is responsible for loading our data.
    # Args in: filepath - the path of the .mat file containing the data
    # Returns: inputs - the data, labels - the labels corresponding to the data, 
    #            patients - the patients corresponding to the data

    inputs_train_folds = np.squeeze(inputs_train_folds)
    inputs_train = np.empty((inputs_train_folds[fold_num].shape[0], inputs_train_folds[fold_num].shape[1]))
    print(inputs_train_folds[fold_num].shape)
    #for i in range(inputs_train.shape[0]):
    inputs_train = inputs_train_folds[fold_num]
            
    labels_train_folds = np.squeeze(labels_train_folds)
    labels_train = np.empty((labels_train_folds[fold_num].shape[0], labels_train_folds[fold_num].shape[1]))
    print(labels_train_folds[fold_num].shape)
    #for i in range(labels_train.shape[0]):
    labels_train = labels_train_folds[fold_num]
        
    patients_train_folds = np.squeeze(patients_train_folds)
    patients_train = np.empty((patients_train_folds.shape[0], patients_train_folds[fold_num].shape[0], inputs_train_folds[fold_num].shape[1]))
    print(patients_train_folds[fold_num].shape)
    #for i in range(patients_train.shape[0]):
    patients_train = patients_train_folds[fold_num]
    
    inputs_val_folds = np.squeeze(inputs_val_folds)
    inputs_val = np.empty((inputs_val_folds[fold_num].shape[0], inputs_val_folds[fold_num].shape[1]))
    print(inputs_val_folds[fold_num].shape)
    #for i in range(inputs_train.shape[0]):
    inputs_val = inputs_val_folds[fold_num]
            
    labels_val_folds = np.squeeze(labels_val_folds)
    labels_val = np.empty((labels_val_folds.shape[0], labels_val_folds[fold_num].shape[0], labels_val_folds[fold_num].shape[1]))
    print(labels_val_folds[fold_num].shape)
    #for i in range(labels_train.shape[0]):
    labels_val = labels_val_folds[fold_num]
        
    patients_val_folds = np.squeeze(patients_val_folds)
    patients_val = np.empty((patients_val_folds.shape[0], patients_val_folds[fold_num].shape[0], patients_val_folds[fold_num].shape[1]))
    print(patients_val_folds[fold_num].shape)
    #for i in range(patients_train.shape[0]):
    patients_val = patients_val_folds[fold_num]
    

    return inputs_train, labels_train, patients_train, inputs_val, labels_val, patients_val

# %%
from sklearn.preprocessing import StandardScaler
def preprocess_data(X_train, X_val):

    # Description: This function preprocesses our data. 
    # We want to ensure that our training data have zero mean and unit variance. 
    # We also use subtract the same mean from the test data and then devide them by
    # the same standard deviation. We do that to ensure that no information about the
    # test set distribution is known ahead of time.

    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    return X_train, X_val

# %%
def one_hot(labels, n_class = 6):
    """ One-hot encoding """
    expansion = np.eye(n_class)
    y = []
    for i in labels:
        y.append(expansion[int(i)])
    y = np.asarray(y)

    return y

# %%
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import keras.backend as K
#from sklearn.metrics import balanced_accuracy_score

class BalancedAccuracy(Callback):
    def __init__(self, train_data, validation_data):
        super(BalancedAccuracy, self).__init__()
        self.acas = []
        self.validation_data = validation_data
        self.train_data = train_data
        
    def on_epoch_end(self, epoch, logs={}):

        X_val = self.validation_data[0]
        y_val = self.validation_data[1]

        X_train = self.train_data[0]
        y_train = self.train_data[1]

        y_val_pred = self.model.predict(X_val)
        y_train_pred = self.model.predict(X_train)

        val_score = self.eval_avg_class_acc(y_val, y_val_pred)
        
        print("\nBalanced Accuracy - val: %.3f"%(val_score))        
        
    def eval_avg_class_acc(self, y_true, y_pred):

        # decode one-hot to single labels
        y_pred = y_pred.round()
        y_pred = [ np.argmax(pred, axis = 0) for pred in y_pred ]
        y_true = [ np.argmax(label, axis = 0) for label in y_true ]

        cf = confusion_matrix(y_true, y_pred)

        class0_acc = float(cf[0][0]) / (float(cf[0][0]) + float(cf[0][1]) + float(cf[0][2]))
        class1_acc = float(cf[1][1]) / (float(cf[1][1]) + float(cf[1][0]) + float(cf[1][2]))
        class2_acc = float(cf[2][2]) / (float(cf[2][2]) + float(cf[2][0]) + float(cf[2][1]))
        balanced_acc = float((class0_acc + class1_acc + class2_acc) / 3)

        return balanced_acc

def weighted_categorical_crossentropy(y_true, y_pred, weights):
    
    weights = K.variable(weights)
        
    # scale predictions so that the class probas of each sample sum to 1
    y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
    # clip to prevent NaN's and Inf's
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # calc
    loss = y_true * K.log(y_pred) * weights
    loss = -K.sum(loss, -1)
    return loss

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def visualize_results(history, model, X_train, y_train_one_hot, X_val, y_val_one_hot):
    print(history.history["acc"][-1])

    # TRAIN SET
    preds = model.predict(X_train)

    # decode one-hot to single labels
    preds = [ np.argmax(pred, axis = 0) for pred in preds ]
    labels = [ np.argmax(label, axis = 0) for label in y_train_one_hot ]

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(labels, preds)
    np.set_printoptions(precision=2)

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                          title='Normalized confusion matrix - Train set - MLP on Raw Data')

    # TEST SET
    preds = model.predict(X_val)

    # decode one-hot to single labels
    preds = [ np.argmax(pred, axis = 0) for pred in preds ]
    labels = [ np.argmax(label, axis = 0) for label in y_val_one_hot ]

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(labels, preds)

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                          title='Normalized confusion matrix - Test set - MLP on Raw Data')

    plt.show()

# %%
def show_results_per_patient(X_val, y_val_one_hot, patients_val, model):
    y_pred = model.predict(X_val)
    y_pred = y_pred.round()
    y_pred = [ np.argmax(pred, axis = 0) for pred in y_pred ]
    y_true = [ np.argmax(label, axis = 0) for label in y_val_one_hot ]
    
    unique, counts = np.unique(patients_val, return_counts=True)
    unique_occurences = dict(zip(unique, counts))
    
    unique_patients = np.unique(patients_val)
    patient_dict = dict.fromkeys(unique_patients)
    majority_voting_dict = dict.fromkeys(unique_patients)
    
    for patient in patient_dict:
        patient_dict[patient] = [0, unique_occurences[patient], 0]
        majority_voting_dict[patient] = [0, 0, 0]
        
    for i in range(0, len(y_pred)):
        if y_pred[i] == y_true[i]:
            patient_dict[patients_val[i]][0] += 1
            patient_dict[patients_val[i]][2] = y_true[i]
        
        majority_voting_dict[patients_val[i]][y_pred[i]] += 1
                
            
    print(patient_dict)
            
    for patient in patient_dict:
        print("Displaying results for patient %d - Accuracy: %.2f"%(patient, float(patient_dict[patient][0]) / float(patient_dict[patient][1])))
    
    total_successfully_classified_patients = 0
    successfully_classified_patients = [0, 0, 0]
    total_patients = [0, 0, 0]
    
    for patient in patient_dict:
        majority_value =  max(majority_voting_dict[patient])
        if patient_dict[patient][0] == majority_value:
            total_successfully_classified_patients += 1
            successfully_classified_patients[patient_dict[patient][2]] += 1
            
        total_patients[patient_dict[patient][2]] += 1
            
    balanced_majority_voting = (float(successfully_classified_patients[0]) / float(total_patients[0]) + float(successfully_classified_patients[1]) / float(total_patients[1]) + float(successfully_classified_patients[2]) / float(total_patients[2])) / 3.0
    print("Displaying majority voting accuracy for the current fold {0}".format(float(total_successfully_classified_patients) / float(len(patient_dict))))
    print("Displaying majority voting balanced accuracy for the current fold {0}".format(balanced_majority_voting))

# %%
def collapse_2nd_dimension(labels_train, patients_train, labels_val, patients_val):   
    labels_train = np.einsum('ij->ji', labels_train)
    labels_train = [label_train for sublist in labels_train for label_train in sublist]
    patients_train = np.einsum('ij->ji', patients_train)
    patients_train = [patient_train for sublist in patients_train for patient_train in sublist]
    
    labels_val = np.einsum('ij->ji', labels_val)
    labels_val = [label_val for sublist in labels_val for label_val in sublist]
    patients_val = np.einsum('ij->ji', patients_val)
    patients_val = [patient_val for sublist in patients_val for patient_val in sublist]
    
    return np.asarray(labels_train), np.asarray(patients_train), np.asarray(labels_val), np.asarray(patients_val)

# %%
from functools import partial
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Activation, BatchNormalization, Reshape
from keras.layers import Dropout
import tensorflow as tf 

for i in range(0,10):
    X_train, y_train, patients_train, X_val, y_val, patients_val = get_train_test_per_fold(inputs_train_folds, labels_train_folds, patients_train_folds, 
                            inputs_val_folds, labels_val_folds, patients_val_folds, i)
    
    y_train, patients_train, y_val, patients_val = collapse_2nd_dimension(y_train, patients_train, y_val, patients_val)
    

    # Weighted loss function to tackle class imbalance in the dataset

    weights = np.array([float(len(y_train)) / float(list(y_train).count(0)), float(len(y_train)) / float(list(y_train).count(1)), float(len(y_train)) / float(list(y_train).count(2))])
    w_cat_crossentropy = partial(weighted_categorical_crossentropy, weights = weights)
    w_cat_crossentropy.__name__ = 'weighted_categorical_crossentropy'
    
    # Balanced accuracy metric definition
    balanced_accuracy = BalancedAccuracy(train_data = (X_train, y_train), validation_data = (X_val, y_val))
    CALLBACKS = [balanced_accuracy]
    
    # Data preprocessing
    X_train, X_val = preprocess_data(X_train, X_val)
    
    
    # Shuffle inputs and labels
    c = list(zip(X_train, y_train, patients_train))
    random.shuffle(c)
    X_train, y_train, patients_train = zip(*c)

    c = list(zip(X_val, y_val, patients_val))
    random.shuffle(c)
    X_val, y_val, patients_val = zip(*c)

    X_train = np.asarray(X_train)
    X_val = np.asarray(X_val)
    
    
    model = Sequential()
    model.add(Dense(256, init='uniform', input_shape = (X_train.shape[1],)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, kernel_initializer="uniform"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation = 'softmax'))

    adam = Adam(lr = 0.01)
    y_train_one_hot = one_hot(y_train, 3)
    y_val_one_hot = one_hot(y_val, 3)

    model.compile(loss=w_cat_crossentropy, optimizer=adam, metrics=['accuracy'])

    history = model.fit(X_train, y_train_one_hot, epochs=300, batch_size=512, validation_data=(X_val, y_val_one_hot), 
              verbose=2, shuffle=True, callbacks=CALLBACKS)
    
    visualize_results(history, model, X_train, y_train_one_hot, X_val, y_val_one_hot)
    
    show_results_per_patient(X_val, y_val_one_hot, patients_val, model)
# Out:
# (17876, 60)
# (17876, 1)
# (17876, 1)
# (1368, 60)
# (1368, 1)
# (1368, 1)
# /home/nikos/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:43: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, input_shape=(60,), kernel_initializer="uniform")`
# Train on 17876 samples, validate on 1368 samples
# Epoch 1/300
#  - 1s - loss: 2.8375 - acc: 0.5590 - val_loss: 4.2078 - val_acc: 0.3911
#
# Balanced Accuracy - val: 0.420
# Epoch 2/300
#  - 1s - loss: 1.9361 - acc: 0.6977 - val_loss: 3.9339 - val_acc: 0.5497
#
# Balanced Accuracy - val: 0.489
# Epoch 3/300
#  - 1s - loss: 1.7060 - acc: 0.7360 - val_loss: 3.5268 - val_acc: 0.5965
#
# Balanced Accuracy - val: 0.528
# Epoch 4/300
#  - 1s - loss: 1.4968 - acc: 0.7686 - val_loss: 3.7149 - val_acc: 0.6096
#
# Balanced Accuracy - val: 0.566
# Epoch 5/300
#  - 1s - loss: 1.3890 - acc: 0.7903 - val_loss: 3.4556 - val_acc: 0.6542
#
# Balanced Accuracy - val: 0.595
# Epoch 6/300
#  - 1s - loss: 1.2998 - acc: 0.7989 - val_loss: 3.3314 - val_acc: 0.6550
#
# Balanced Accuracy - val: 0.611
# Epoch 7/300
#  - 1s - loss: 1.2328 - acc: 0.8108 - val_loss: 3.3413 - val_acc: 0.6645
#
# Balanced Accuracy - val: 0.627
# Epoch 8/300
#  - 1s - loss: 1.1851 - acc: 0.8214 - val_loss: 3.0614 - val_acc: 0.6754
#
# Balanced Accuracy - val: 0.643
# Epoch 9/300
#  - 1s - loss: 1.1349 - acc: 0.8275 - val_loss: 3.5677 - val_acc: 0.6871
#
# Balanced Accuracy - val: 0.653
# Epoch 10/300
#  - 1s - loss: 1.0902 - acc: 0.8338 - val_loss: 3.0498 - val_acc: 0.6996
#
# Balanced Accuracy - val: 0.676
# Epoch 11/300
#  - 1s - loss: 1.0483 - acc: 0.8415 - val_loss: 3.3168 - val_acc: 0.6923
#
# Balanced Accuracy - val: 0.662
# Epoch 12/300
#  - 1s - loss: 1.0412 - acc: 0.8400 - val_loss: 3.3672 - val_acc: 0.6630
#
# Balanced Accuracy - val: 0.634
# Epoch 13/300
#  - 1s - loss: 1.0374 - acc: 0.8412 - val_loss: 3.1640 - val_acc: 0.6901
#
# Balanced Accuracy - val: 0.663
# Epoch 14/300
#  - 1s - loss: 0.9953 - acc: 0.8481 - val_loss: 3.1086 - val_acc: 0.6908
#
# Balanced Accuracy - val: 0.656
# Epoch 15/300
#  - 1s - loss: 0.9683 - acc: 0.8505 - val_loss: 2.9572 - val_acc: 0.6974
#
# Balanced Accuracy - val: 0.675
# Epoch 16/300
#  - 1s - loss: 0.9640 - acc: 0.8543 - val_loss: 2.9902 - val_acc: 0.6871
#
# Balanced Accuracy - val: 0.666
# Epoch 17/300
#  - 1s - loss: 0.9157 - acc: 0.8599 - val_loss: 3.2559 - val_acc: 0.6908
#
# Balanced Accuracy - val: 0.676
# Epoch 18/300
#  - 1s - loss: 0.9061 - acc: 0.8648 - val_loss: 3.0730 - val_acc: 0.6871
#
# Balanced Accuracy - val: 0.658
# Epoch 19/300
#  - 1s - loss: 0.9125 - acc: 0.8615 - val_loss: 3.1169 - val_acc: 0.7091
#
# Balanced Accuracy - val: 0.677
# Epoch 20/300
#  - 1s - loss: 0.8806 - acc: 0.8661 - val_loss: 2.8644 - val_acc: 0.7003
#
# Balanced Accuracy - val: 0.688
# Epoch 21/300
#  - 1s - loss: 0.8619 - acc: 0.8688 - val_loss: 3.3349 - val_acc: 0.6952
#
# Balanced Accuracy - val: 0.681
# Epoch 22/300
#  - 1s - loss: 0.8697 - acc: 0.8681 - val_loss: 2.9032 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.694
# Epoch 23/300
#  - 1s - loss: 0.8703 - acc: 0.8685 - val_loss: 3.1526 - val_acc: 0.7120
#
# Balanced Accuracy - val: 0.693
# Epoch 24/300
#  - 1s - loss: 0.8384 - acc: 0.8703 - val_loss: 3.2626 - val_acc: 0.7127
#
# Balanced Accuracy - val: 0.687
# Epoch 25/300
#  - 1s - loss: 0.8360 - acc: 0.8721 - val_loss: 3.1563 - val_acc: 0.7076
#
# Balanced Accuracy - val: 0.690
# Epoch 26/300
#  - 1s - loss: 0.8537 - acc: 0.8703 - val_loss: 3.1797 - val_acc: 0.7113
#
# Balanced Accuracy - val: 0.690
# Epoch 27/300
#  - 1s - loss: 0.8350 - acc: 0.8714 - val_loss: 3.3720 - val_acc: 0.7178
#
# Balanced Accuracy - val: 0.693
# Epoch 28/300
#  - 1s - loss: 0.8024 - acc: 0.8783 - val_loss: 3.2028 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.707
# Epoch 29/300
#  - 1s - loss: 0.8033 - acc: 0.8794 - val_loss: 3.2549 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.703
# Epoch 30/300
#  - 1s - loss: 0.7902 - acc: 0.8808 - val_loss: 3.0737 - val_acc: 0.7120
#
# Balanced Accuracy - val: 0.710
# Epoch 31/300
#  - 1s - loss: 0.8165 - acc: 0.8761 - val_loss: 3.2583 - val_acc: 0.7361
#
# Balanced Accuracy - val: 0.724
# Epoch 32/300
#  - 1s - loss: 0.7992 - acc: 0.8781 - val_loss: 3.3191 - val_acc: 0.7230
#
# Balanced Accuracy - val: 0.707
# Epoch 33/300
#  - 1s - loss: 0.7752 - acc: 0.8810 - val_loss: 3.1778 - val_acc: 0.7113
#
# Balanced Accuracy - val: 0.700
# Epoch 34/300
#  - 1s - loss: 0.7922 - acc: 0.8792 - val_loss: 2.8764 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.703
# Epoch 35/300
#  - 1s - loss: 0.7868 - acc: 0.8794 - val_loss: 2.9931 - val_acc: 0.7171
#
# Balanced Accuracy - val: 0.700
# Epoch 36/300
#  - 1s - loss: 0.7801 - acc: 0.8789 - val_loss: 3.0436 - val_acc: 0.7259
#
# Balanced Accuracy - val: 0.712
# Epoch 37/300
#  - 1s - loss: 0.7735 - acc: 0.8855 - val_loss: 3.1105 - val_acc: 0.7317
#
# Balanced Accuracy - val: 0.715
# Epoch 38/300
#  - 1s - loss: 0.7375 - acc: 0.8882 - val_loss: 3.2095 - val_acc: 0.7237
#
# Balanced Accuracy - val: 0.713
# Epoch 39/300
#  - 1s - loss: 0.7516 - acc: 0.8867 - val_loss: 3.1612 - val_acc: 0.7215
#
# Balanced Accuracy - val: 0.704
# Epoch 40/300
#  - 1s - loss: 0.7719 - acc: 0.8833 - val_loss: 3.0280 - val_acc: 0.7288
#
# Balanced Accuracy - val: 0.710
# Epoch 41/300
#  - 1s - loss: 0.7592 - acc: 0.8856 - val_loss: 2.9756 - val_acc: 0.7537
#
# Balanced Accuracy - val: 0.734
# Epoch 42/300
#  - 1s - loss: 0.7556 - acc: 0.8848 - val_loss: 3.1133 - val_acc: 0.7156
#
# Balanced Accuracy - val: 0.698
# Epoch 43/300
#  - 1s - loss: 0.7517 - acc: 0.8863 - val_loss: 3.0020 - val_acc: 0.7281
#
# Balanced Accuracy - val: 0.714
# Epoch 44/300
#  - 1s - loss: 0.7137 - acc: 0.8933 - val_loss: 3.1262 - val_acc: 0.7273
#
# Balanced Accuracy - val: 0.711
# Epoch 45/300
#  - 1s - loss: 0.7234 - acc: 0.8902 - val_loss: 3.1007 - val_acc: 0.7127
#
# Balanced Accuracy - val: 0.696
# Epoch 46/300
#  - 1s - loss: 0.7173 - acc: 0.8919 - val_loss: 3.3918 - val_acc: 0.7485
#
# Balanced Accuracy - val: 0.724
# Epoch 47/300
#  - 1s - loss: 0.7238 - acc: 0.8920 - val_loss: 3.1261 - val_acc: 0.7522
#
# Balanced Accuracy - val: 0.736
# Epoch 48/300
#  - 1s - loss: 0.7026 - acc: 0.8944 - val_loss: 3.2562 - val_acc: 0.7412
#
# Balanced Accuracy - val: 0.719
# Epoch 49/300
#  - 1s - loss: 0.6969 - acc: 0.8956 - val_loss: 3.3225 - val_acc: 0.7456
#
# Balanced Accuracy - val: 0.732
# Epoch 50/300
#  - 1s - loss: 0.7126 - acc: 0.8918 - val_loss: 3.4820 - val_acc: 0.7200
#
# Balanced Accuracy - val: 0.701
# Epoch 51/300
#  - 1s - loss: 0.6863 - acc: 0.8971 - val_loss: 3.3434 - val_acc: 0.7529
#
# Balanced Accuracy - val: 0.736
# Epoch 52/300
#  - 1s - loss: 0.7049 - acc: 0.8931 - val_loss: 3.5820 - val_acc: 0.7303
#
# Balanced Accuracy - val: 0.718
# Epoch 53/300
#  - 1s - loss: 0.6779 - acc: 0.8977 - val_loss: 3.2581 - val_acc: 0.7639
#
# Balanced Accuracy - val: 0.754
# Epoch 54/300
#  - 0s - loss: 0.7101 - acc: 0.8942 - val_loss: 3.1229 - val_acc: 0.7361
#
# Balanced Accuracy - val: 0.717
# Epoch 55/300
#  - 1s - loss: 0.6666 - acc: 0.8999 - val_loss: 3.3701 - val_acc: 0.7500
#
# Balanced Accuracy - val: 0.736
# Epoch 56/300
#  - 1s - loss: 0.6934 - acc: 0.8955 - val_loss: 3.0898 - val_acc: 0.7522
#
# Balanced Accuracy - val: 0.738
# Epoch 57/300
#  - 1s - loss: 0.6834 - acc: 0.8972 - val_loss: 3.1921 - val_acc: 0.7471
#
# Balanced Accuracy - val: 0.738
# Epoch 58/300
#  - 1s - loss: 0.6648 - acc: 0.8982 - val_loss: 3.1709 - val_acc: 0.7500
#
# Balanced Accuracy - val: 0.736
# Epoch 59/300
#  - 1s - loss: 0.6716 - acc: 0.8991 - val_loss: 3.3259 - val_acc: 0.7332
#
# Balanced Accuracy - val: 0.719
# Epoch 60/300
#  - 1s - loss: 0.6652 - acc: 0.9001 - val_loss: 3.1178 - val_acc: 0.7456
#
# Balanced Accuracy - val: 0.735
# Epoch 61/300
#  - 1s - loss: 0.6831 - acc: 0.8976 - val_loss: 3.2574 - val_acc: 0.7215
#
# Balanced Accuracy - val: 0.711
# Epoch 62/300
#  - 1s - loss: 0.6578 - acc: 0.9023 - val_loss: 3.1975 - val_acc: 0.7558
#
# Balanced Accuracy - val: 0.743
# Epoch 63/300
#  - 1s - loss: 0.6747 - acc: 0.9018 - val_loss: 3.4806 - val_acc: 0.7442
#
# Balanced Accuracy - val: 0.735
# Epoch 64/300
#  - 1s - loss: 0.6795 - acc: 0.8978 - val_loss: 3.1844 - val_acc: 0.7449
#
# Balanced Accuracy - val: 0.735
# Epoch 65/300
#  - 1s - loss: 0.6831 - acc: 0.9007 - val_loss: 3.3398 - val_acc: 0.7588
#
# Balanced Accuracy - val: 0.744
# Epoch 66/300
#  - 1s - loss: 0.6330 - acc: 0.9076 - val_loss: 3.5202 - val_acc: 0.7456
#
# Balanced Accuracy - val: 0.729
# Epoch 67/300
#  - 1s - loss: 0.6493 - acc: 0.9031 - val_loss: 3.0962 - val_acc: 0.7580
#
# Balanced Accuracy - val: 0.741
# Epoch 68/300
#  - 1s - loss: 0.6464 - acc: 0.9038 - val_loss: 3.2609 - val_acc: 0.7420
#
# Balanced Accuracy - val: 0.728
# Epoch 69/300
#  - 1s - loss: 0.6562 - acc: 0.9020 - val_loss: 3.0926 - val_acc: 0.7493
#
# Balanced Accuracy - val: 0.742
# Epoch 70/300
#  - 1s - loss: 0.6530 - acc: 0.9013 - val_loss: 3.0597 - val_acc: 0.7588
#
# Balanced Accuracy - val: 0.752
# Epoch 71/300
#  - 1s - loss: 0.6435 - acc: 0.9034 - val_loss: 2.9560 - val_acc: 0.7442
#
# Balanced Accuracy - val: 0.733
# Epoch 72/300
#  - 1s - loss: 0.6583 - acc: 0.9046 - val_loss: 3.2367 - val_acc: 0.7537
#
# Balanced Accuracy - val: 0.743
# Epoch 73/300
#  - 1s - loss: 0.6515 - acc: 0.9017 - val_loss: 3.0958 - val_acc: 0.7544
#
# Balanced Accuracy - val: 0.751
# Epoch 74/300
#  - 1s - loss: 0.6304 - acc: 0.9057 - val_loss: 3.2594 - val_acc: 0.7449
#
# Balanced Accuracy - val: 0.733
# Epoch 75/300
#  - 1s - loss: 0.6331 - acc: 0.9066 - val_loss: 3.4204 - val_acc: 0.7529
#
# Balanced Accuracy - val: 0.744
# Epoch 76/300
#  - 1s - loss: 0.6298 - acc: 0.9093 - val_loss: 3.5518 - val_acc: 0.7456
#
# Balanced Accuracy - val: 0.737
# Epoch 77/300
#  - 1s - loss: 0.6029 - acc: 0.9106 - val_loss: 3.0058 - val_acc: 0.7632
#
# Balanced Accuracy - val: 0.748
# Epoch 78/300
#  - 1s - loss: 0.6483 - acc: 0.9051 - val_loss: 3.2806 - val_acc: 0.7632
#
# Balanced Accuracy - val: 0.755
# Epoch 79/300
#  - 1s - loss: 0.6204 - acc: 0.9067 - val_loss: 3.5319 - val_acc: 0.7398
#
# Balanced Accuracy - val: 0.735
# Epoch 80/300
#  - 1s - loss: 0.6247 - acc: 0.9073 - val_loss: 3.6315 - val_acc: 0.7515
#
# Balanced Accuracy - val: 0.739
# Epoch 81/300
#  - 1s - loss: 0.6065 - acc: 0.9093 - val_loss: 3.6455 - val_acc: 0.7675
#
# Balanced Accuracy - val: 0.759
# Epoch 82/300
#  - 1s - loss: 0.6138 - acc: 0.9070 - val_loss: 4.0957 - val_acc: 0.7427
#
# Balanced Accuracy - val: 0.736
# Epoch 83/300
#  - 1s - loss: 0.6519 - acc: 0.9055 - val_loss: 3.5782 - val_acc: 0.7522
#
# Balanced Accuracy - val: 0.741
# Epoch 84/300
#  - 1s - loss: 0.6005 - acc: 0.9090 - val_loss: 3.5318 - val_acc: 0.7580
#
# Balanced Accuracy - val: 0.747
# Epoch 85/300
#  - 1s - loss: 0.5992 - acc: 0.9112 - val_loss: 3.4004 - val_acc: 0.7749
#
# Balanced Accuracy - val: 0.766
# Epoch 86/300
#  - 1s - loss: 0.6188 - acc: 0.9103 - val_loss: 3.1032 - val_acc: 0.7654
#
# Balanced Accuracy - val: 0.755
# Epoch 87/300
- val_acc: 0.7537
#
# Balanced Accuracy - val: 0.746
# Epoch 109/300
#  - 1s - loss: 0.6047 - acc: 0.9129 - val_loss: 3.1550 - val_acc: 0.7339
#
# Balanced Accuracy - val: 0.727
# Epoch 110/300
#  - 1s - loss: 0.5911 - acc: 0.9133 - val_loss: 3.3672 - val_acc: 0.7449
#
# Balanced Accuracy - val: 0.732
# Epoch 111/300
#  - 1s - loss: 0.5999 - acc: 0.9121 - val_loss: 3.3047 - val_acc: 0.7544
#
# Balanced Accuracy - val: 0.742
# Epoch 112/300
#  - 1s - loss: 0.5826 - acc: 0.9147 - val_loss: 3.5314 - val_acc: 0.7412
#
# Balanced Accuracy - val: 0.733
# Epoch 113/300
#  - 1s - loss: 0.5763 - acc: 0.9149 - val_loss: 3.6151 - val_acc: 0.7383
#
# Balanced Accuracy - val: 0.734
# Epoch 114/300
#  - 1s - loss: 0.5993 - acc: 0.9136 - val_loss: 3.4557 - val_acc: 0.7697
#
# Balanced Accuracy - val: 0.760
# Epoch 115/300
#  - 1s - loss: 0.5979 - acc: 0.9122 - val_loss: 3.5601 - val_acc: 0.7507
#
# Balanced Accuracy - val: 0.740
# Epoch 116/300
#  - 1s - loss: 0.5777 - acc: 0.9133 - val_loss: 3.5522 - val_acc: 0.7588
#
# Balanced Accuracy - val: 0.746
# Epoch 117/300
#  - 1s - loss: 0.5931 - acc: 0.9151 - val_loss: 3.1926 - val_acc: 0.7610
#
# Balanced Accuracy - val: 0.751
# Epoch 118/300
#  - 1s - loss: 0.5595 - acc: 0.9170 - val_loss: 3.3314 - val_acc: 0.7617
#
# Balanced Accuracy - val: 0.754
# Epoch 119/300
#  - 1s - loss: 0.5691 - acc: 0.9143 - val_loss: 3.7262 - val_acc: 0.7566
#
# Balanced Accuracy - val: 0.746
# Epoch 120/300
#  - 1s - loss: 0.5578 - acc: 0.9213 - val_loss: 3.4170 - val_acc: 0.7654
#
# Balanced Accuracy - val: 0.759
# Epoch 121/300
#  - 1s - loss: 0.5847 - acc: 0.9143 - val_loss: 3.4635 - val_acc: 0.7471
#
# Balanced Accuracy - val: 0.741
# Epoch 122/300
#  - 1s - loss: 0.5519 - acc: 0.9191 - val_loss: 3.4521 - val_acc: 0.7398
#
# Balanced Accuracy - val: 0.732
# Epoch 123/300
#  - 1s - loss: 0.5735 - acc: 0.9170 - val_loss: 3.4755 - val_acc: 0.7368
#
# Balanced Accuracy - val: 0.724
# Epoch 124/300
#  - 1s - loss: 0.5564 - acc: 0.9203 - val_loss: 3.4383 - val_acc: 0.7485
#
# Balanced Accuracy - val: 0.737
# Epoch 125/300
#  - 1s - loss: 0.5567 - acc: 0.9180 - val_loss: 3.3573 - val_acc: 0.7405
#
# Balanced Accuracy - val: 0.727
# Epoch 126/300
#  - 1s - loss: 0.6031 - acc: 0.9151 - val_loss: 3.3980 - val_acc: 0.7295
#
# Balanced Accuracy - val: 0.721
# Epoch 127/300
#  - 1s - loss: 0.5694 - acc: 0.9159 - val_loss: 3.5202 - val_acc: 0.7412
#
# Balanced Accuracy - val: 0.730
# Epoch 128/300
#  - 1s - loss: 0.5723 - acc: 0.9178 - val_loss: 3.5502 - val_acc: 0.7566
#
# Balanced Accuracy - val: 0.749
# Epoch 129/300
#  - 1s - loss: 0.5470 - acc: 0.9187 - val_loss: 3.5861 - val_acc: 0.7705
#
# Balanced Accuracy - val: 0
# Epoch 285/300
#  - 1s - loss: 0.4853 - acc: 0.9316 - val_loss: 3.5793 - val_acc: 0.7734
#
# Balanced Accuracy - val: 0.769
# Epoch 286/300
#  - 1s - loss: 0.4885 - acc: 0.9303 - val_loss: 3.4946 - val_acc: 0.7610
#
# Balanced Accuracy - val: 0.760
# Epoch 287/300
#  - 1s - loss: 0.4453 - acc: 0.9325 - val_loss: 4.1800 - val_acc: 0.7558
#
# Balanced Accuracy - val: 0.754
# Epoch 288/300
#  - 1s - loss: 0.4506 - acc: 0.9361 - val_loss: 3.7563 - val_acc: 0.7624
#
# Balanced Accuracy - val: 0.759
# Epoch 289/300
#  - 1s - loss: 0.4536 - acc: 0.9348 - val_loss: 3.9318 - val_acc: 0.7617
#
# Balanced Accuracy - val: 0.760
# Epoch 290/300
#  - 1s - loss: 0.4894 - acc: 0.9305 - val_loss: 3.5715 - val_acc: 0.7661
#
# Balanced Accuracy - val: 0.761
# Epoch 291/300
#  - 1s - loss: 0.4774 - acc: 0.9305 - val_loss: 3.5031 - val_acc: 0.7770
#
# Balanced Accuracy - val: 0.773
# Epoch 292/300
#  - 1s - loss: 0.4519 - acc: 0.9324 - val_loss: 3.9898 - val_acc: 0.7807
#
# Balanced Accuracy - val: 0.777
# Epoch 293/300
#  - 1s - loss: 0.4862 - acc: 0.9331 - val_loss: 3.8302 - val_acc: 0.7675
#
# Balanced Accuracy - val: 0.762
# Epoch 294/300
#  - 1s - loss: 0.4719 - acc: 0.9323 - val_loss: 4.1375 - val_acc: 0.7792
#
# Balanced Accuracy - val: 0.770
# Epoch 295/300
#  - 1s - loss: 0.4661 - acc: 0.9353 - val_loss: 3.9117 - val_acc: 0.7624
#
# Balanced Accuracy - val: 0.756
# Epoch 296/300
#  - 1s - loss: 0.4989 - acc: 0.9298 - val_loss: 3.9496 - val_acc: 0.7690
#
# Balanced Accuracy - val: 0.762
# Epoch 297/300
#  - 1s - loss: 0.4909 - acc: 0.9307 - val_loss: 4.1877 - val_acc: 0.7741
#
# Balanced Accuracy - val: 0.768
# Epoch 298/300
#  - 1s - loss: 0.4707 - acc: 0.9306 - val_loss: 4.0973 - val_acc: 0.7675
#
# Balanced Accuracy - val: 0.761
# Epoch 299/300
#  - 1s - loss: 0.5007 - acc: 0.9306 - val_loss: 3.8808 - val_acc: 0.7690
#
# Balanced Accuracy - val: 0.763
# Epoch 300/300
#  - 1s - loss: 0.4920 - acc: 0.9272 - val_loss: 4.1823 - val_acc: 0.7668
#
# Balanced Accuracy - val: 0.762
# 0.927220855284
# {1007: [2, 2], 1017: [5, 9], 1093: [333, 354], 1119: [3, 3], 2094: [304, 440], 2102: [18, 20], 3070: [35, 58], 3117: [0, 21], 3525: [2, 7], 3578: [248, 325], 3592: [91, 129]}
# Displaying results for patient 1007 - Accuracy: 1.00
# Displaying results for patient 1017 - Accuracy: 0.56
# Displaying results for patient 1093 - Accuracy: 0.94
# Displaying results for patient 1119 - Accuracy: 1.00
# Displaying results for patient 2094 - Accuracy: 0.69
# Displaying results for patient 2102 - Accuracy: 0.90
# Displaying results for patient 3070 - Accuracy: 0.60
# Displaying results for patient 3117 - Accuracy: 0.00
# Displaying results for patient 3525 - Accuracy: 0.29
# Displaying results for patient 3578 - Accuracy: 0.76
# Displaying results for patient 3592 - Accuracy: 0.71
# Displaying majority voting accuracy for the current fold 0.8181818181818182
# (16603, 60)
# (16603, 1)
# (16603, 1)
# (2641, 60)
# (2641, 1)
# (2641, 1)
# Train on 16603 samples, validate on 2641 samples
# Epoch 1/300
#  - 1s - loss: 2.9178 - acc: 0.5323 - val_loss: 3.7019 - val_acc: 0.4771
#
# Balanced Accuracy - val: 0.517
# Epoch 2/300
#  - 0s - loss: 2.0338 - acc: 0.6793 - val_loss: 3.2532 - val_acc: 0.6051
#
# Balanced Accuracy - val: 0.600
# Epoch 3/300
#  - 0s - loss: 1.7872 - acc: 0.7263 - val_loss: 2.8632 - val_acc: 0.6577
#
# Balanced Accuracy - val: 0.621
# Epoch 4/300
#  - 0s - loss: 1.5633 - acc: 0.7605 - val_loss: 2.7400 - val_acc: 0.7058
#
# Balanced Accuracy - val: 0.641
# Epoch 5/300
#  - 0s - loss: 1.4499 - acc: 0.7843 - val_loss: 2.4107 - val_acc: 0.7175
#
# Balanced Accuracy - val: 0.704
# Epoch 6/300
#  - 1s - loss: 1.3383 - acc: 0.7982 - val_loss: 2.0544 - val_acc: 0.7535
#
# Balanced Accuracy - val: 0.729
# Epoch 7/300
#  - 1s - loss: 1.3005 - acc: 0.8000 - val_loss: 1.9637 - val_acc: 0.7603
#
# Balanced Accuracy - val: 0.752
# Epoch 8/300
#  - 1s - loss: 1.2108 - acc: 0.8177 - val_loss: 1.7062 - val_acc: 0.7902
#
# Balanced Accuracy - val: 0.775
# Epoch 9/300
#  - 1s - loss: 1.1834 - acc: 0.8192 - val_loss: 1.8621 - val_acc: 0.7751
#
# Balanced Accuracy - val: 0.775
# Epoch 10/300
#  - 1s - loss: 1.1290 - acc: 0.8339 - val_loss: 1.7702 - val_acc: 0.7917
#
# Balanced Accuracy - val: 0.782
# Epoch 11/300
#  - 1s - loss: 1.1023 - acc: 0.8314 - val_loss: 1.5954 - val_acc: 0.8042
#
# Balanced Accuracy - val: 0.804
# Epoch 12/300
#  - 1s - loss: 1.0791 - acc: 0.8391 - val_loss: 1.6987 - val_acc: 0.7921
#
# Balanced Accuracy - val: 0.792
# Epoch 13/300
#  - 1s - loss: 1.0285 - acc: 0.8414 - val_loss: 1.9080 - val_acc: 0.7815
#
# Balanced Accuracy - val: 0.775
# Epoch 14/300
#  - 1s - loss: 1.0043 - acc: 0.8435 - val_loss: 1.9040 - val_acc: 0.7929
#
# Balanced Accuracy - val: 0.777
# Epoch 15/300
#  - 0s - loss: 1.0189 - acc: 0.8452 - val_loss: 1.9945 - val_acc: 0.7815
#
# Balanced Accuracy - val: 0.774
# Epoch 16/300
#  - 1s - loss: 0.9839 - acc: 0.8532 - val_loss: 1.7056 - val_acc: 0.7876
#
# Balanced Accuracy - val: 0.795
# Epoch 17/300
#  - 0s - loss: 0.9626 - acc: 0.8554 - val_loss: 1.5736 - val_acc: 0.8031
#
# Balanced Accuracy - val: 0.793
# Epoch 18/300
#  - 1s - loss: 0.9569 - acc: 0.8590 - val_loss: 1.8454 - val_acc: 0.7789
#
# Balanced Accuracy - val: 0.788
# Epoch 19/300
#  - 1s - loss: 0.9230 - acc: 0.8595 - val_loss: 1.8133 - val_acc: 0.7982
#
# Balanced Accuracy - val: 0.784
# Epoch 20/300
#  - 1s - loss: 0.9255 - acc: 0.8610 - val_loss: 1.9935 - val_acc: 0.7827
#
# Balanced Accuracy - val: 0.782
# Epoch 21/300
#  - 1s - loss: 0.8949 - acc: 0.8645 - val_loss: 1.6271 - val_acc: 0.7986
#
# Balanced Accuracy - val: 0.811
# Epoch 22/300
#  - 1s - loss: 0.9099 - acc: 0.8633 - val_loss: 1.5564 - val_acc: 0.8073
#
# Balanced Accuracy - val: 0.801
# Epoch 23/300
#  - 0s - loss: 0.8738 - acc: 0.8677 - val_loss: 1.6983 - val_acc: 0.8039
#
# Balanced Accuracy - val: 0.805
# Epoch 24/300
#  - 1s - loss: 0.8656 - acc: 0.8682 - val_loss: 1.7889 - val_acc: 0.7963
#
# Balanced Accuracy - val: 0.803
# Epoch 25/300
#  - 1s - loss: 0.8797 - acc: 0.8683 - val_loss: 1.5799 - val_acc: 0.8148
#
# Balanced Accuracy - val: 0.821
# Epoch 26/300
#  - 1s - loss: 0.8514 - acc: 0.8719 - val_loss: 1.6747 - val_acc: 0.8107
#
# Balanced Accuracy - val: 0.811
# Epoch 27/300
#  - 1s - loss: 0.8322 - acc: 0.8763 - val_loss: 1.5834 - val_acc: 0.8175
#
# Balanced Accuracy - val: 0.830
# Epoch 28/300
#  - 0s - loss: 0.8495 - acc: 0.8733 - val_loss: 1.6111 - val_acc: 0.8031
#
# Balanced Accuracy - val: 0.807
# Epoch 29/300
#  - 1s - loss: 0.8172 - acc: 0.8772 - val_loss: 1.7167 - val_acc: 0.7993
#
# Balanced Accuracy - val: 0.798
# Epoch 30/300
#  - 1s - loss: 0.8202 - acc: 0.8787 - val_loss: 1.9172 - val_acc: 0.7914
#
# Balanced Accuracy - val: 0.795
# Epoch 31/300
#  - 1s - loss: 0.8362 - acc: 0.8741 - val_loss: 1.7274 - val_acc: 0.7917
#
# Balanced Accuracy - val: 0.809
# Epoch 32/300
#  - 1s - loss: 0.8177 - acc: 0.8773 - val_loss: 1.6557 - val_acc: 0.8039
#
# Balanced Accuracy - val: 0.816
# Epoch 33/300
#  - 1s - loss: 0.8074 - acc: 0.8830 - val_loss: 1.6651 - val_acc: 0.8095
#
# Balanced Accuracy - val: 0.815
# Epoch 34/300
#  - 1s - loss: 0.7939 - acc: 0.8768 - val_loss: 1.8634 - val_acc: 0.7989
#
# Balanced Accuracy - val: 0.800
# Epoch 35/300
#  - 1s - loss: 0.7936 - acc: 0.8842 - val_loss: 1.7166 - val_acc: 0.8027
#
# Balanced Accuracy - val: 0.808
# Epoch 36/300
#  - 1s - loss: 0.7843 - acc: 0.8851 - val_loss: 1.6311 - val_acc: 0.8111
#
# Balanced Accuracy - val: 0.806
# Epoch 37/300
#  - 1s - loss: 0.7839 - acc: 0.8863 - val_loss: 1.5367 - val_acc: 0.8145
#
# Balanced Accuracy - val: 0.812
# Epoch 38/300
#  - 1s - loss: 0.7759 - acc: 0.8859 - val_loss: 1.7539 - val_acc: 0.8061
#
# Balanced Accuracy - val: 0.803
# Epoch 39/300
#  - 1s - loss: 0.7542 - acc: 0.8888 - val_loss: 1.6005 - val_acc: 0.8118
#
# Balanced Accuracy - val: 0.821
# Epoch 40/300
#  - 1s - loss: 0.7592 - acc: 0.8871 - val_loss: 1.4840 - val_acc: 0.8190
#
# Balanced Accuracy - val: 0.824
# Epoch 41/300
#  - 1s - loss: 0.7417 - acc: 0.8929 - val_loss: 1.5925 - val_acc: 0.8099
#
# Balanced Accuracy - val: 0.820
# Epoch 42/300
#  - 1s - loss: 0.7679 - acc: 0.8883 - val_loss: 1.7966 - val_acc: 0.7974
#
# Balanced Accuracy - val: 0.808
# Epoch 43/300
#  - 1s - loss: 0.7253 - acc: 0.8915 - val_loss: 1.7356 - val_acc: 0.8118
#
# Balanced Accuracy - val: 0.803
# Epoch 44/300
#  - 1s - loss: 0.7281 - acc: 0.8912 - val_loss: 1.9183 - val_acc: 0.7815
#
# Balanced Accuracy - val: 0.804
# Epoch 45/300
#  - 1s - loss: 0.7220 - acc: 0.8918 - val_loss: 1.8447 - val_acc: 0.8012
#
# Balanced Accuracy - val: 0.803
# Epoch 46/300
#  - 0s - loss: 0.7127 - acc: 0.8937 - val_loss: 1.7715 - val_acc: 0.8008
#
# Balanced Accuracy - val: 0.816
# Epoch 47/300
#  - 1s - loss: 0.7117 - acc: 0.8961 - val_loss: 1.7711 - val_acc: 0.8092
#
# Balanced Accuracy - val: 0.802
# Epoch 48/300
#  - 1s - loss: 0.7184 - acc: 0.8938 - val_loss: 1.7571 - val_acc: 0.7948
#
# Balanced Accuracy - val: 0.818
# Epoch 49/300
#  - 1s - loss: 0.7258 - acc: 0.8908 - val_loss: 1.8111 - val_acc: 0.7944
#
# Balanced Accuracy - val: 0.810
# Epoch 50/300
#  - 1s - loss: 0.7204 - acc: 0.8924 - val_loss: 1.7033 - val_acc: 0.8080
#
# Balanced Accuracy - val: 0.813
# Epoch 51/300
#  - 1s - loss: 0.7303 - acc: 0.8956 - val_loss: 1.8792 - val_acc: 0.8001
#
# Balanced Accuracy - val: 0.799
# Epoch 52/300
#  - 1s - loss: 0.6881 - acc: 0.8962 - val_loss: 1.8002 - val_acc: 0.7967
#
# Balanced Accuracy - val: 0.817
# Epoch 53/300
#  - 1s - loss: 0.7014 - acc: 0.8985 - val_loss: 1.6058 - val_acc: 0.8042
#
# Balanced Accuracy - val: 0.813
# Epoch 54/300
#  - 1s - loss: 0.7103 - acc: 0.8944 - val_loss: 1.7658 - val_acc: 0.8076
#
# Balanced Accuracy - val: 0.812
# Epoch 55/300
#  - 1s - loss: 0.7214 - acc: 0.8970 - val_loss: 1.6671 - val_acc: 0.8099
#
# Balanced Accuracy - val: 0.819
# Epoch 56/300
#  - 1s - loss: 0.6901 - acc: 0.8991 - val_loss: 1.6296 - val_acc: 0.8133
#
# Balanced Accuracy - val: 0.821
# Epoch 57/300
#  - 1s - loss: 0.6789 - acc: 0.8995 - val_loss: 1.7047 - val_acc: 0.8148
#
# Balanced Accuracy - val: 0.820
# Epoch 58/300
#  - 1s - loss: 0.6836 - acc: 0.9007 - val_loss: 1.8371 - val_acc: 0.7868
#
# Balanced Accuracy - val: 0.808
# Epoch 59/300
#  - 1s - loss: 0.6917 - acc: 0.8988 - val_loss: 1.9979 - val_acc: 0.7989
#
# Balanced Accuracy - val: 0.797
# Epoch 60/300
#  - 1s - loss: 0.6704 - acc: 0.9021 - val_loss: 1.7627 - val_acc: 0.8126
#
# Balanced Accuracy - val: 0.814
# Epoch 61/300
#  - 1s - loss: 0.6947 - acc: 0.8977 - val_loss: 1.6242 - val_acc: 0.8061
#
# Balanced Accuracy - val: 0.823
# Epoch 62/300
#  - 1s - loss: 0.6828 - acc: 0.9012 - val_loss: 1.6073 - val_acc: 0.8141
#
# Balanced Accuracy - val: 0.829
# Epoch 63/300
#  - 0s - loss: 0.6588 - acc: 0.9044 - val_loss: 1.5966 - val_acc: 0.8088
#
# Balanced Accuracy - val: 0.828
# Epoch 64/300
#  - 0s - loss: 0.6697 - acc: 0.8998 - val_loss: 1.8234 - val_acc: 0.8095
#
# Balanced Accuracy - val: 0.817
# Epoch 65/300
#  - 1s - loss: 0.6899 - acc: 0.8984 - val_loss: 1.6120 - val_acc: 0.8217
#
# Balanced Accuracy - val: 0.825
# Epoch 66/300
#  - 1s - loss: 0.6611 - acc: 0.9057 - val_loss: 1.7475 - val_acc: 0.8205
#
# Balanced Accuracy - val: 0.815
# Epoch 67/300
#  - 1s - loss: 0.6523 - acc: 0.9050 - val_loss: 1.6758 - val_acc: 0.8145
#
# Balanced Accuracy - val: 0.823
# Epoch 68/300
#  - 1s - loss: 0.6604 - acc: 0.9038 - val_loss: 1.7906 - val_acc: 0.8103
#
# Balanced Accuracy - val: 0.811
# Epoch 69/300
#  - 1s - loss: 0.6293 - acc: 0.9059 - val_loss: 1.7447 - val_acc: 0.8171
#
# Balanced Accuracy - val: 0.830
# Epoch 70/300
#  - 1s - loss: 0.6256 - acc: 0.9083 - val_loss: 1.6483 - val_acc: 0.8247
#
# Balanced Accuracy - val: 0.830
# Epoch 71/300
#  - 1s - loss: 0.6426 - acc: 0.9081 - val_loss: 1.6602 - val_acc: 0.8076
#
# Balanced Accuracy - val: 0.823
# Epoch 72/300
#  - 1s - loss: 0.6797 - acc: 0.9021 - val_loss: 1.5750 - val_acc: 0.8141
#
# Balanced Accuracy - val: 0.816
# Epoch 73/300
#  - 1s - loss: 0.6416 - acc: 0.9041 - val_loss: 1.6796 - val_acc: 0.8114
#
# Balanced Accuracy - val: 0.820
# Epoch 74/300
#  - 1s - loss: 0.6475 - acc: 0.9085 - val_loss: 1.8511 - val_acc: 0.8076
#
# Balanced Accuracy - val: 0.815
# Epoch 75/300
#  - 1s - loss: 0.6628 - acc: 0.9021 - val_loss: 1.6755 - val_acc: 0.8095
#
# Balanced Accuracy - val: 0.815
# Epoch 76/300
#  - 1s - loss: 0.6333 - acc: 0.9089 - val_loss: 1.7560 - val_acc: 0.8126
#
# Balanced Accuracy - val: 0.820
# Epoch 77/300
#  - 1s - loss: 0.6391 - acc: 0.9078 - val_loss: 1.8172 - val_acc: 0.8092
#
# Balanced Accuracy - val: 0.821
# Epoch 78/300
#  - 1s - loss: 0.6601 - acc: 0.9043 - val_loss: 1.6756 - val_acc: 0.8129
#
# Balanced Accuracy - val: 0.824
# Epoch 79/300
#  - 1s - loss: 0.6395 - acc: 0.9078 - val_loss: 1.8331 - val_acc: 0.8111
#
# Balanced Accuracy - val: 0.809
# Epoch 80/300
#  - 1s - loss: 0.6169 - acc: 0.9115 - val_loss: 1.8252 - val_acc: 0.8054
#
# Balanced Accuracy - val: 0.819
# Epoch 81/300
#  - 1s - loss: 0.6175 - acc: 0.9082 - val_loss: 1.8847 - val_acc: 0.8058
#
# Balanced Accuracy - val: 0.810
# Epoch 82/300
#  - 1s - loss: 0.6372 - acc: 0.9075 - val_loss: 1.9974 - val_acc: 0.7944
#
# Balanced Accuracy - val: 0.812
# Epoch 83/300
#  - 1s - loss: 0.6562 - acc: 0.9100 - val_loss: 1.4657 - val_acc: 0.8315
#
# Balanced Accuracy - val: 0.834
# Epoch 84/300
#  - 1s - loss: 0.6454 - acc: 0.9010 - val_loss: 1.6120 - val_acc: 0.8266
#
# Balanced Accuracy - val: 0.828
# Epoch 85/300
#  - 1s - loss: 0.6497 - acc: 0.9042 - val_loss: 1.5459 - val_acc: 0.8277
#
# Balanced Accuracy - val: 0.831
# Epoch 86/300
#  - 1s - loss: 0.6111 - acc: 0.9122 - val_loss: 1.6513 - val_acc: 0.8266
#
# Balanced Accuracy - val: 0.830
# Epoch 87/300
#  - 1s - loss: 0.6561 - acc: 0.9050 - val_loss: 1.7377 - val_acc: 0.8311
#
# Balanced Accuracy - val: 0.829
# Epoch 88/300
#  - 1s - loss: 0.6364 - acc: 0.9053 - val_loss: 1.5888 - val_acc: 0.8164
#
# Balanced Accuracy - val: 0.830
# Epoch 89/300
#  - 1s - loss: 0.6468 - acc: 0.9063 - val_loss: 1.7325 - val_acc: 0.8023
#
# Balanced Accuracy - val: 0.820
# Epoch 90/300
#  - 1s - loss: 0.6292 - acc: 0.9088 - val_loss: 1.8115 - val_acc: 0.8141
#
# Balanced Accuracy - val: 0.817
# Epoch 91/300
#  - 1s - loss: 0.6267 - acc: 0.9092 - val_loss: 1.5992 - val_acc: 0.8349
#
# Balanced Accuracy - val: 0.828
# Epoch 92/300
#  - 1s - loss: 0.6547 - acc: 0.9033 - val_loss: 1.7084 - val_acc: 0.8137
#
# Balanced Accuracy - val: 0.823
# Epoch 93/300
#  - 1s - loss: 0.6262 - acc: 0.9099 - val_loss: 1.6256 - val_acc: 0.8122
#
# Balanced Accuracy - val: 0.828
# Epoch 94/300
#  - 1s - loss: 0.6089 - acc: 0.9140 - val_loss: 1.7217 - val_acc: 0.8088
#
# Balanced Accuracy - val: 0.820
# Epoch 95/300
#  - 1s - loss: 0.6423 - acc: 0.9030 - val_loss: 1.7038 - val_acc: 0.8167
#
# Balanced Accuracy - val: 0.824
# Epoch 96/300
#  - 1s - loss: 0.6217 - acc: 0.9137 - val_loss: 1.7216 - val_acc: 0.8129
#
# Balanced Accuracy - val: 0.823
# Epoch 97/300
#  - 1s - loss: 0.6076 - acc: 0.9101 - val_loss: 1.5450 - val_acc: 0.8266
#
# Balanced Accuracy - val: 0.822
# Epoch 98/300
#  - 0s - loss: 0.6061 - acc: 0.9129 - val_loss: 1.8563 - val_acc: 0.8058
#
# ...
#
# Balanced Accuracy - val: 0.890
# Epoch 173/300
#  - 1s - loss: 0.5367 - acc: 0.9256 - val_loss: 0.8615 - val_acc: 0.8606
#
# Balanced Accuracy - val: 0.897
# Epoch 174/300
#  - 1s - loss: 0.5609 - acc: 0.9194 - val_loss: 0.8149 - val_acc: 0.8612
#
# Balanced Accuracy - val: 0.893
# Epoch 175/300
#  - 1s - loss: 0.5546 - acc: 0.9199 - val_loss: 0.8079 - val_acc: 0.8606
#
# Balanced Accuracy - val: 0.891
# Epoch 176/300
#  - 1s - loss: 0.5440 - acc: 0.9255 - val_loss: 0.7822 - val_acc: 0.8662
#
# Balanced Accuracy - val: 0.893
# Epoch 177/300
#  - 1s - loss: 0.5233 - acc: 0.9249 - val_loss: 0.7698 - val_acc: 0.8599
#
# Balanced Accuracy - val: 0.887
# Epoch 178/300
#  - 1s - loss: 0.5620 - acc: 0.9219 - val_loss: 0.8479 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.889
# Epoch 179/300
#  - 1s - loss: 0.5391 - acc: 0.9237 - val_loss: 0.8087 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.887
# Epoch 180/300
#  - 1s - loss: 0.5478 - acc: 0.9209 - val_loss: 0.7217 - val_acc: 0.8694
#
# Balanced Accuracy - val: 0.894
# Epoch 181/300
#  - 1s - loss: 0.5553 - acc: 0.9216 - val_loss: 0.7350 - val_acc: 0.8732
#
# Balanced Accuracy - val: 0.897
# Epoch 182/300
#  - 1s - loss: 0.5464 - acc: 0.9236 - val_loss: 0.7785 - val_acc: 0.8694
#
# Balanced Accuracy - val: 0.900
# Epoch 183/300
#  - 1s - loss: 0.5204 - acc: 0.9268 - val_loss: 0.8061 - val_acc: 0.8593
#
# Balanced Accuracy - val: 0.896
# Epoch 184/300
#  - 1s - loss: 0.5601 - acc: 0.9230 - val_loss: 0.8394 - val_acc: 0.8524
#
# Balanced Accuracy - val: 0.886
# Epoch 185/300
#  - 1s - loss: 0.5460 - acc: 0.9266 - val_loss: 0.7845 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.896
# Epoch 186/300
#  - 1s - loss: 0.5445 - acc: 0.9238 - val_loss: 0.8343 - val_acc: 0.8511
#
# Balanced Accuracy - val: 0.880
# Epoch 187/300
#  - 1s - loss: 0.5730 - acc: 0.9211 - val_loss: 0.8896 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.894
# Epoch 188/300
#  - 1s - loss: 0.5199 - acc: 0.9269 - val_loss: 0.8828 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.891
# Epoch 189/300
#  - 1s - loss: 0.5477 - acc: 0.9252 - val_loss: 0.8116 - val_acc: 0.8612
#
# Balanced Accuracy - val: 0.895
# Epoch 190/300
#  - 1s - loss: 0.5614 - acc: 0.9230 - val_loss: 0.8213 - val_acc: 0.8580
#
# Balanced Accuracy - val: 0.892
# Epoch 191/300
#  - 1s - loss: 0.5350 - acc: 0.9252 - val_loss: 0.7849 - val_acc: 0.8694
#
# Balanced Accuracy - val: 0.897
# Epoch 192/300
#  - 1s - loss: 0.5428 - acc: 0.9256 - val_loss: 0.8001 - val_acc: 0.8675
#
# Balanced Accuracy - val: 0.897
# Epoch 193/300
#  - 1s - loss: 0.5443 - acc: 0.9241 - val_loss: 0.7953 - val_acc: 0.8580
#
# Balanced Accuracy - val: 0.889
# Epoch 194/300
#  - 1s - loss: 0.5620 - acc: 0.9211 - val_loss: 0.8681 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.894
# Epoch 195/300
#  - 1s - loss: 0.5572 - acc: 0.9241 - val_loss: 0.8414 - val_acc: 0.8618
#
# Balanced Accuracy - val: 0.895
# Epoch 196/300
#  - 1s - loss: 0.5514 - acc: 0.9225 - val_loss: 0.8247 - val_acc: 0.8644
#
# Balanced Accuracy - val: 0.896
# Epoch 197/300
#  - 1s - loss: 0.5201 - acc: 0.9271 - val_loss: 0.8798 - val_acc: 0.8549
#
# Balanced Accuracy - val: 0.891
# Epoch 198/300
#  - 1s - loss: 0.5276 - acc: 0.9246 - val_loss: 0.8319 - val_acc: 0.8599
#
# Balanced Accuracy - val: 0.894
# Epoch 199/300
#  - 1s - loss: 0.5704 - acc: 0.9224 - val_loss: 0.7669 - val_acc: 0.8669
#
# Balanced Accuracy - val: 0.895
# Epoch 200/300
#  - 1s - loss: 0.5491 - acc: 0.9229 - val_loss: 0.8040 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.893
# Epoch 201/300
#  - 1s - loss: 0.5323 - acc: 0.9235 - val_loss: 0.8417 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.893
# Epoch 202/300
#  - 1s - loss: 0.5431 - acc: 0.9242 - val_loss: 0.7947 - val_acc: 0.8580
#
# Balanced Accuracy - val: 0.888
# Epoch 203/300
#  - 1s - loss: 0.5208 - acc: 0.9266 - val_loss: 0.7902 - val_acc: 0.8644
#
# Balanced Accuracy - val: 0.892
# Epoch 204/300
#  - 1s - loss: 0.5119 - acc: 0.9285 - val_loss: 0.8742 - val_acc: 0.8599
#
# Balanced Accuracy - val: 0.895
# Epoch 205/300
#  - 1s - loss: 0.5034 - acc: 0.9290 - val_loss: 0.8177 - val_acc: 0.8612
#
# Balanced Accuracy - val: 0.889
# Epoch 206/300
#  - 1s - loss: 0.5427 - acc: 0.9252 - val_loss: 0.7847 - val_acc: 0.8644
#
# Balanced Accuracy - val: 0.894
# Epoch 207/300
#  - 1s - loss: 0.5088 - acc: 0.9311 - val_loss: 0.7889 - val_acc: 0.8744
#
# Balanced Accuracy - val: 0.900
# Epoch 208/300
#  - 1s - loss: 0.5520 - acc: 0.9244 - val_loss: 0.7769 - val_acc: 0.8707
#
# Balanced Accuracy - val: 0.897
# Epoch 209/300
#  - 1s - loss: 0.5309 - acc: 0.9243 - val_loss: 0.8186 - val_acc: 0.8549
#
# Balanced Accuracy - val: 0.889
# Epoch 210/300
#  - 1s - loss: 0.5273 - acc: 0.9233 - val_loss: 0.7624 - val_acc: 0.8669
#
# Balanced Accuracy - val: 0.899
# Epoch 211/300
#  - 1s - loss: 0.5194 - acc: 0.9255 - val_loss: 0.7412 - val_acc: 0.8820
#
# Balanced Accuracy - val: 0.906
# Epoch 212/300
#  - 1s - loss: 0.5041 - acc: 0.9274 - val_loss: 0.7875 - val_acc: 0.8719
#
# Balanced Accuracy - val: 0.904
# Epoch 213/300
#  - 1s - loss: 0.5296 - acc: 0.9277 - val_loss: 0.7430 - val_acc: 0.8789
#
# Balanced Accuracy - val: 0.907
# Epoch 214/300
#  - 1s - loss: 0.5378 - acc: 0.9250 - val_loss: 0.7742 - val_acc: 0.8707
#
# Balanced Accuracy - val: 0.898
# Epoch 215/300
#  - 1s - loss: 0.5170 - acc: 0.9302 - val_loss: 0.7987 - val_acc: 0.8675
#
# Balanced Accuracy - val: 0.897
# Epoch 216/300
#  - 1s - loss: 0.5317 - acc: 0.9268 - val_loss: 0.7673 - val_acc: 0.8681
#
# Balanced Accuracy - val: 0.894
# Epoch 217/300
#  - 1s - loss: 0.5417 - acc: 0.9245 - val_loss: 0.8392 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.892
# Epoch 218/300
#  - 1s - loss: 0.5179 - acc: 0.9276 - val_loss: 0.7766 - val_acc: 0.8744
#
# Balanced Accuracy - val: 0.901
# Epoch 219/300
#  - 1s - loss: 0.5455 - acc: 0.9260 - val_loss: 0.7182 - val_acc: 0.8814
#
# Balanced Accuracy - val: 0.905
# Epoch 220/300
#  - 1s - loss: 0.4982 - acc: 0.9274 - val_loss: 0.8613 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.900
# Epoch 221/300
#  - 1s - loss: 0.5059 - acc: 0.9303 - val_loss: 0.7677 - val_acc: 0.8738
#
# Balanced Accuracy - val: 0.900
# Epoch 222/300
#  - 1s - loss: 0.4951 - acc: 0.9300 - val_loss: 0.8154 - val_acc: 0.8675
#
# Balanced Accuracy - val: 0.897
# Epoch 223/300
#  - 1s - loss: 0.5384 - acc: 0.9241 - val_loss: 0.8630 - val_acc: 0.8524
#
# Balanced Accuracy - val: 0.889
# Epoch 224/300
#  - 1s - loss: 0.5541 - acc: 0.9254 - val_loss: 0.7409 - val_acc: 0.8744
#
# Balanced Accuracy - val: 0.901
# Epoch 225/300
#  - 1s - loss: 0.5326 - acc: 0.9293 - val_loss: 0.7734 - val_acc: 0.8751
#
# Balanced Accuracy - val: 0.899
# Epoch 226/300
#  - 1s - loss: 0.5415 - acc: 0.9225 - val_loss: 0.8072 - val_acc: 0.8662
#
# Balanced Accuracy - val: 0.896
# Epoch 227/300
#  - 1s - loss: 0.5047 - acc: 0.9291 - val_loss: 0.7641 - val_acc: 0.8700
#
# Balanced Accuracy - val: 0.896
# Epoch 228/300
#  - 1s - loss: 0.5197 - acc: 0.9294 - val_loss: 0.7943 - val_acc: 0.8732
#
# Balanced Accuracy - val: 0.898
# Epoch 229/300
#  - 1s - loss: 0.4888 - acc: 0.9327 - val_loss: 0.7814 - val_acc: 0.8719
#
# Balanced Accuracy - val: 0.901
# Epoch 230/300
#  - 1s - loss: 0.5085 - acc: 0.9292 - val_loss: 0.8456 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.897
# Epoch 231/300
#  - 1s - loss: 0.5148 - acc: 0.9303 - val_loss: 0.8348 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.898
# Epoch 232/300
#  - 1s - loss: 0.5095 - acc: 0.9301 - val_loss: 0.8403 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.891
# Epoch 233/300
#  - 1s - loss: 0.5213 - acc: 0.9298 - val_loss: 0.8051 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.894
# Epoch 234/300
#  - 1s - loss: 0.5304 - acc: 0.9273 - val_loss: 0.7555 - val_acc: 0.8744
#
# Balanced Accuracy - val: 0.904
# Epoch 235/300
#  - 1s - loss: 0.5334 - acc: 0.9268 - val_loss: 0.8369 - val_acc: 0.8631
#
# Balanced Accuracy - val: 0.895
# Epoch 236/300
#  - 1s - loss: 0.5441 - acc: 0.9255 - val_loss: 0.9045 - val_acc: 0.8473
#
# Balanced Accuracy - val: 0.886
# Epoch 237/300
#  - 1s - loss: 0.5179 - acc: 0.9294 - val_loss: 0.8411 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.893
# Epoch 238/300
#  - 1s - loss: 0.5079 - acc: 0.9289 - val_loss: 0.7954 - val_acc: 0.8707
#
# Balanced Accuracy - val: 0.899
# Epoch 239/300
#  - 1s - loss: 0.5015 - acc: 0.9286 - val_loss: 0.8296 - val_acc: 0.8612
#
# Balanced Accuracy - val: 0.896
# Epoch 240/300
#  - 1s - loss: 0.5357 - acc: 0.9222 - val_loss: 0.9050 - val_acc: 0.8461
#
# Balanced Accuracy - val: 0.886
# Epoch 241/300
#  - 1s - loss: 0.5165 - acc: 0.9269 - val_loss: 0.8136 - val_acc: 0.8662
#
# Balanced Accuracy - val: 0.895
# Epoch 242/300
#  - 1s - loss: 0.5088 - acc: 0.9292 - val_loss: 0.8134 - val_acc: 0.8669
#
# Balanced Accuracy - val: 0.897
# Epoch 243/300
#  - 1s - loss: 0.4944 - acc: 0.9318 - val_loss: 0.8173 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.891
# Epoch 244/300
#  - 1s - loss: 0.4925 - acc: 0.9298 - val_loss: 0.7656 - val_acc: 0.8707
#
# Balanced Accuracy - val: 0.902
# Epoch 245/300
#  - 1s - loss: 0.5089 - acc: 0.9294 - val_loss: 0.8266 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.892
# Epoch 246/300
#  - 1s - loss: 0.4892 - acc: 0.9311 - val_loss: 0.7986 - val_acc: 0.8656
#
# Balanced Accuracy - val: 0.897
# Epoch 247/300
#  - 1s - loss: 0.5007 - acc: 0.9296 - val_loss: 0.8736 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.888
# Epoch 248/300
#  - 1s - loss: 0.5267 - acc: 0.9276 - val_loss: 0.8594 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.891
# Epoch 249/300
#  - 1s - loss: 0.5174 - acc: 0.9288 - val_loss: 0.8154 - val_acc: 0.8650
#
# Balanced Accuracy - val: 0.893
# Epoch 250/300
#  - 1s - loss: 0.5048 - acc: 0.9298 - val_loss: 0.7738 - val_acc: 0.8681
#
# Balanced Accuracy - val: 0.895
# Epoch 251/300
#  - 1s - loss: 0.5074 - acc: 0.9296 - val_loss: 0.8288 - val_acc: 0.8574
#
# Balanced Accuracy - val: 0.887
# Epoch 252/300
#  - 1s - loss: 0.5221 - acc: 0.9281 - val_loss: 0.8256 - val_acc: 0.8549
#
# Balanced Accuracy - val: 0.886
# Epoch 253/300
#  - 1s - loss: 0.5194 - acc: 0.9255 - val_loss: 0.8026 - val_acc: 0.8599
#
# Balanced Accuracy - val: 0.892
# Epoch 254/300
#  - 1s - loss: 0.4992 - acc: 0.9287 - val_loss: 0.8328 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.891
# Epoch 255/300
#  - 1s - loss: 0.5080 - acc: 0.9293 - val_loss: 0.7608 - val_acc: 0.8763
#
# Balanced Accuracy - val: 0.901
# Epoch 256/300
#  - 1s - loss: 0.5184 - acc: 0.9286 - val_loss: 0.7932 - val_acc: 0.8656
#
# Balanced Accuracy - val: 0.893
# Epoch 257/300
#  - 1s - loss: 0.5352 - acc: 0.9256 - val_loss: 0.7706 - val_acc: 0.8662
#
# Balanced Accuracy - val: 0.895
# Epoch 258/300
#  - 1s - loss: 0.4988 - acc: 0.9322 - val_loss: 0.8326 - val_acc: 0.8562
#
# Balanced Accuracy - val: 0.889
# Epoch 259/300
#  - 1s - loss: 0.4931 - acc: 0.9311 - val_loss: 0.8078 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.890
# Epoch 260/300
#  - 1s - loss: 0.4903 - acc: 0.9293 - val_loss: 0.8135 - val_acc: 0.8536
#
# Balanced Accuracy - val: 0.887
# Epoch 261/300
#  - 1s - loss: 0.4938 - acc: 0.9306 - val_loss: 0.8456 - val_acc: 0.8517
#
# Balanced Accuracy - val: 0.887
# Epoch 262/300
#  - 1s - loss: 0.5031 - acc: 0.9292 - val_loss: 0.7697 - val_acc: 0.8688
#
# Balanced Accuracy - val: 0.898
# Epoch 263/300
#  - 1s - loss: 0.4803 - acc: 0.9304 - val_loss: 0.7780 - val_acc: 0.8688
#
# Balanced Accuracy - val: 0.894
# Epoch 264/300
#  - 1s - loss: 0.4883 - acc: 0.9343 - val_loss: 0.7615 - val_acc: 0.8707
#
# Balanced Accuracy - val: 0.898
# Epoch 265/300
#  - 1s - loss: 0.4974 - acc: 0.9328 - val_loss: 0.8057 - val_acc: 0.8618
#
# Balanced Accuracy - val: 0.893
# Epoch 266/300
#  - 1s - loss: 0.4924 - acc: 0.9297 - val_loss: 0.8357 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.889
# Epoch 267/300
#  - 1s - loss: 0.4913 - acc: 0.9328 - val_loss: 0.7839 - val_acc: 0.8675
#
# Balanced Accuracy - val: 0.896
# Epoch 268/300
#  - 1s - loss: 0.5089 - acc: 0.9293 - val_loss: 0.9032 - val_acc: 0.8517
#
# Balanced Accuracy - val: 0.887
# Epoch 269/300
#  - 1s - loss: 0.4912 - acc: 0.9334 - val_loss: 0.8690 - val_acc: 0.8524
#
# Balanced Accuracy - val: 0.888
# Epoch 270/300
#  - 1s - loss: 0.5048 - acc: 0.9311 - val_loss: 0.8374 - val_acc: 0.8555
#
# Balanced Accuracy - val: 0.891
# Epoch 271/300
#  - 1s - loss: 0.5015 - acc: 0.9323 - val_loss: 0.8324 - val_acc: 0.8631
#
# Balanced Accuracy - val: 0.896
# Epoch 272/300
#  - 1s - loss: 0.4893 - acc: 0.9314 - val_loss: 0.7817 - val_acc: 0.8694
#
# Balanced Accuracy - val: 0.902
# Epoch 273/300
#  - 1s - loss: 0.5028 - acc: 0.9290 - val_loss: 0.8261 - val_acc: 0.8593
#
# Balanced Accuracy - val: 0.892
# Epoch 274/300
#  - 1s - loss: 0.4831 - acc: 0.9339 - val_loss: 0.7978 - val_acc: 0.8656
#
# Balanced Accuracy - val: 0.892
# Epoch 275/300
#  - 1s - loss: 0.4853 - acc: 0.9323 - val_loss: 0.8291 - val_acc: 0.8562
#
# Balanced Accuracy - val: 0.892
# Epoch 276/300
#  - 1s - loss: 0.4887 - acc: 0.9339 - val_loss: 0.8090 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.897
# Epoch 277/300
#  - 1s - loss: 0.4999 - acc: 0.9298 - val_loss: 0.8542 - val_acc: 0.8574
#
# Balanced Accuracy - val: 0.889
# Epoch 278/300
#  - 1s - loss: 0.4919 - acc: 0.9306 - val_loss: 0.8290 - val_acc: 0.8618
#
# Balanced Accuracy - val: 0.892
# Epoch 279/300
#  - 1s - loss: 0.5131 - acc: 0.9286 - val_loss: 0.8382 - val_acc: 0.8599
#
# Balanced Accuracy - val: 0.894
# Epoch 280/300
#  - 1s - loss: 0.5020 - acc: 0.9323 - val_loss: 0.7908 - val_acc: 0.8650
#
# Balanced Accuracy - val: 0.894
# Epoch 281/300
#  - 1s - loss: 0.5199 - acc: 0.9280 - val_loss: 0.8408 - val_acc: 0.8498
#
# Balanced Accuracy - val: 0.886
# Epoch 282/300
#  - 1s - loss: 0.4916 - acc: 0.9334 - val_loss: 0.8064 - val_acc: 0.8631
#
# Balanced Accuracy - val: 0.893
# Epoch 283/300
#  - 1s - loss: 0.4959 - acc: 0.9330 - val_loss: 0.8377 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.892
# Epoch 284/300
#  - 1s - loss: 0.4800 - acc: 0.9350 - val_loss: 0.8355 - val_acc: 0.8580
#
# Balanced Accuracy - val: 0.894
# Epoch 285/300
#  - 1s - loss: 0.4733 - acc: 0.9331 - val_loss: 0.8283 - val_acc: 0.8612
#
# Balanced Accuracy - val: 0.895
# Epoch 286/300
#  - 1s - loss: 0.4724 - acc: 0.9343 - val_loss: 0.8364 - val_acc: 0.8637
#
# Balanced Accuracy - val: 0.893
# Epoch 287/300
#  - 1s - loss: 0.4808 - acc: 0.9333 - val_loss: 0.7886 - val_acc: 0.8700
#
# Balanced Accuracy - val: 0.894
# Epoch 288/300
#  - 1s - loss: 0.4749 - acc: 0.9342 - val_loss: 0.8023 - val_acc: 0.8625
#
# Balanced Accuracy - val: 0.893
# Epoch 289/300
#  - 1s - loss: 0.4990 - acc: 0.9324 - val_loss: 0.8289 - val_acc: 0.8656
#
# Balanced Accuracy - val: 0.894
# Epoch 290/300
#  - 1s - loss: 0.4973 - acc: 0.9331 - val_loss: 0.8599 - val_acc: 0.8492
#
# Balanced Accuracy - val: 0.885
# Epoch 291/300
#  - 1s - loss: 0.4654 - acc: 0.9321 - val_loss: 0.7639 - val_acc: 0.8744
#
# Balanced Accuracy - val: 0.900
# Epoch 292/300
#  - 1s - loss: 0.5011 - acc: 0.9313 - val_loss: 0.8173 - val_acc: 0.8618
#
# Balanced Accuracy - val: 0.895
# Epoch 293/300
#  - 1s - loss: 0.4868 - acc: 0.9321 - val_loss: 0.8731 - val_acc: 0.8549
#
# Balanced Accuracy - val: 0.891
# Epoch 294/300
#  - 1s - loss: 0.4901 - acc: 0.9341 - val_loss: 0.8330 - val_acc: 0.8587
#
# Balanced Accuracy - val: 0.888
# Epoch 295/300
#  - 1s - loss: 0.5101 - acc: 0.9283 - val_loss: 0.8013 - val_acc: 0.8650
#
# Balanced Accuracy - val: 0.893
# Epoch 296/300
#  - 1s - loss: 0.4580 - acc: 0.9392 - val_loss: 0.8825 - val_acc: 0.8511
#
# Balanced Accuracy - val: 0.888
# Epoch 297/300
#  - 1s - loss: 0.4959 - acc: 0.9323 - val_loss: 0.9380 - val_acc: 0.8511
#
# Balanced Accuracy - val: 0.887
# Epoch 298/300
#  - 1s - loss: 0.5011 - acc: 0.9273 - val_loss: 0.8653 - val_acc: 0.8543
#
# Balanced Accuracy - val: 0.891
# Epoch 299/300
#  - 1s - loss: 0.4848 - acc: 0.9309 - val_loss: 0.7513 - val_acc: 0.8757
#
# Balanced Accuracy - val: 0.899
# Epoch 300/300
#  - 1s - loss: 0.4912 - acc: 0.9290 - val_loss: 0.7896 - val_acc: 0.8618
#
# Balanced Accuracy - val: 0.893
# 0.928988051807
# {1012: [29, 34], 1090: [83, 145], 1094: [45, 50], 1098: [6, 7], 1101: [106, 110], 2098: [414, 503], 2104: [293, 296], 2111: [66, 75], 2615: [298, 330], 3033: [3, 5], 3084: [20, 30]}
# Displaying results for patient 1012 - Accuracy: 0.85
# Displaying results for patient 1090 - Accuracy: 0.57
# Displaying results for patient 1094 - Accuracy: 0.90
# Displaying results for patient 1098 - Accuracy: 0.86
# Displaying results for patient 1101 - Accuracy: 0.96
# Displaying results for patient 2098 - Accuracy: 0.82
# Displaying results for patient 2104 - Accuracy: 0.99
# Displaying results for patient 2111 - Accuracy: 0.88
# Displaying results for patient 2615 - Accuracy: 0.90
# Displaying results for patient 3033 - Accuracy: 0.60
# Displaying results for patient 3084 - Accuracy: 0.67
# Displaying majority voting accuracy for the current fold 1.0
