# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D, UpSampling1D
from keras.optimizers import Adam, RMSprop, SGD
from sklearn.cross_validation import KFold
import matplotlib.cm as cm
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
import scipy.io
# Out:
# Using TensorFlow backend.
# /Users/Nikos/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Setting the random seeds
random.seed(1)
np.random.seed(1337)

# %%
def load_data(filepath):

# Description: This function is responsible for loading our data.
# Args in: filepath - the path of the .mat file containing the data
# Returns: inputs - the data, labels - the labels corresponding to the data, 
#            patients - the patients corresponding to the data

    mat = scipy.io.loadmat(filepath)
    inputs = mat['U0_new'][:]
    labels = mat['Y']
    patients = mat['patientID']

    labels = np.einsum('ij->ji', labels)
    labels = [label for sublist in labels for label in sublist]
    patients = np.einsum('ij->ji', patients)
    patients = [patient for sublist in patients for patient in sublist]

    return inputs, labels, patients

# %%
def filter_duplicates(duplicates_list, inputs, targets, patients):

# Description: This function is responsible for filtering out
# some patients that are found to be present in more than one classes.
# Args in & Returns are self-explanatory.
    
    patients = list(patients)
    
    duplicate_indices = []
    for duplicate in duplicates_list:
        #patients = list(filter(lambda a: a != duplicate, patients))
        for i in range(len(patients)):
            if patients[i] == duplicate:
                duplicate_indices.append(i)
    
    duplicate_indices = set(duplicate_indices)
    all_indices = set([i for i in range(len(patients))])
    valid_indices = set(all_indices - duplicate_indices)
    inputs = [inputs[i] for i in valid_indices]
    targets = [targets[i] for i in valid_indices]
    patients = [patients[i] for i in valid_indices]
    
    return inputs, targets, np.asarray(patients)

# %%
inputs, labels, patients = load_data('/Users/Nikos/Desktop/MyResearch/Zacharaki/PARAFACmissingvalues0_90/ReconstructedTensorAndFeatures90Missing_StrSGD.mat')

# %%
inputs, labels, patients = filter_duplicates([1002, 1104], inputs, labels, patients)

# %%
def split_train_test(inputs, targets, patients, patients_for_test):

# Description: This function is responsible for splitting our data into training and test data
# Args in: patients_for_val - list containing the patients for our test data
# Returns: the data and labels of our training and test data

    X_train_size = X_test_size = 0

    patients_for_train = [item for item in list(np.unique(patients)) if item not in patients_for_test]
    idpatients_test = []
    for patient in patients_for_test:
        idpatient = [i for i, x in enumerate(patients) if x == patient]
        idpatients_test.append(idpatient)
    idpatients_test = [item for sublist in idpatients_test for item in sublist]
    X_test = [inputs[i] for i in idpatients_test]
    y_test = [targets[i] for i in idpatients_test]
    patients_test = [patients[i] for i in idpatients_test]
    
    #print(inputs.shape)
    idpatients_train = list(set([i for i in range(inputs.shape[0])]) - set(idpatients_test))
    #print(idpatients_train)
    inputs = [inputs[i] for i in idpatients_train]
    targets = [targets[i] for i in idpatients_train]
    patients_train = [patients[i] for i in idpatients_train]
    
    return np.asarray(inputs), np.asarray(targets), np.asarray(patients_train), np.asarray(X_test), np.asarray(y_test), np.asarray(patients_test)

def split_train_val(inputs, targets, patients, patients_for_val):

# Description: This function is responsible for splitting our data into training and validation data
# Args in: patients_for_val - list containing the patients for our validation data
# Returns: the data and labels of our training and validation data

    X_train_size = X_val_size = 0

    patients_for_train = [item for item in list(np.unique(patients)) if item not in patients_for_val]
    idpatients_val = []
    for patient in patients_for_val:
        idpatient = [i-1 for i, x in enumerate(patients) if x == patient]
        idpatients_val.append(idpatient)
    idpatients_val = [item for sublist in idpatients_val for item in sublist]
    X_val = [inputs[i] for i in idpatients_val]
    y_val = [targets[i] for i in idpatients_val]
    
    idpatients_train = list(set([i for i in range(inputs.shape[0])]) - set(idpatients_val))
    inputs = [inputs[i] for i in idpatients_train]
    y_train = [targets[i] for i in idpatients_train]

    return np.asarray(inputs), np.asarray(X_val), np.asarray(y_train), np.asarray(y_val)

# %%
inputs = np.asarray(inputs)
labels = np.asarray(labels)
X_train, y_train, patients_train, X_test, y_test, patients_test = split_train_test(inputs, labels, patients, [1106, 1107, 2097])
X_train, X_val, y_train, y_val = split_train_val(X_train, y_train, patients_train, [1006, 3026, 2104])
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape)
# Out:
# (16556, 60) (16556,) (1393, 60) (1393,) (333, 60) (333,)

# %%
from sklearn.preprocessing import StandardScaler
def preprocess_data(X_train, X_val, X_test):

# Description: This function preprocesses our data. 
# We want to ensure that our training data have zero mean and unit variance. 
# We also use subtract the same mean from the test data and then devide them by
# the same standard deviation. We do that to ensure that no information about the
# test set distribution is known ahead of time.

# Args in & Returns are self-explanatory.
    #scalers = {}
    scaler = StandardScaler()
    """
    for i in range(X_train.shape[2]):
        scalers[i] = StandardScaler()
        X_train[:, i, :] = scalers[i].fit_transform(X_train[:, i, :])
    
    for i in range(X_test.shape[2]):
        X_val[:, i, :] = scalers[i].transform(X_val[:, i, :]) 
        
    for i in range(X_test.shape[2]):
        X_test[:, i, :] = scalers[i].transform(X_test[:, i, :]) 
    """
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    #X_train = (X_train - np.mean(X_train, axis=0)) / np.std(X_train, axis = 0)
    
    #X_val = (X_val - np.mean(X_train, axis=0)) / np.std(X_train, axis = 0)
    
    #X_test = (X_test -  np.mean(X_train, axis=0)) / np.std(X_train, axis = 0)
    
    #X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1] * X_test.shape[2]))
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
    #X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1] * X_val.shape[2]))
    
    return X_train, X_val, X_test

# %%
X_train, X_val, X_test = preprocess_data(X_train, X_val, X_test)

# %%
c = list(zip(X_train, y_train))
random.shuffle(c)
X_train, y_train = zip(*c)

c = list(zip(X_test, y_test))
random.shuffle(c)
X_test, y_test = zip(*c)

X_train = np.asarray(X_train)
X_test = np.asarray(X_test)

# %%
def one_hot(labels, n_class = 6):
    """ One-hot encoding """
    expansion = np.eye(n_class)
    y = []
    for i in labels:
        y.append(expansion[int(i)])
    y = np.asarray(y)

    return y

# %%
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import keras.backend as K
#from sklearn.metrics import balanced_accuracy_score

class BalancedAccuracy(Callback):
    def __init__(self, train_data, validation_data):
        super(BalancedAccuracy, self).__init__()
        self.acas = []
        self.validation_data = validation_data
        self.train_data = train_data
        
    def on_epoch_end(self, epoch, logs={}):

        X_val = self.validation_data[0]
        y_val = self.validation_data[1]

        X_train = self.train_data[0]
        y_train = self.train_data[1]

        y_val_pred = self.model.predict(X_val)
        y_train_pred = self.model.predict(X_train)

        val_score = self.eval_avg_class_acc(y_val, y_val_pred)
        
        print("\nBalanced Accuracy - val: %.3f"%(val_score))        
        
    def eval_avg_class_acc(self, y_true, y_pred):

        # decode one-hot to single labels
        y_pred = y_pred.round()
        y_pred = [ np.argmax(pred, axis = 0) for pred in y_pred ]
        y_true = [ np.argmax(label, axis = 0) for label in y_true ]

        cf = confusion_matrix(y_true, y_pred)

        class0_acc = float(cf[0][0]) / (float(cf[0][0]) + float(cf[0][1]) + float(cf[0][2]))
        class1_acc = float(cf[1][1]) / (float(cf[1][1]) + float(cf[1][0]) + float(cf[1][2]))
        class2_acc = float(cf[2][2]) / (float(cf[2][2]) + float(cf[2][0]) + float(cf[2][1]))
        balanced_acc = float((class0_acc + class1_acc + class2_acc) / 3)

        return balanced_acc

def weighted_categorical_crossentropy(y_true, y_pred, weights):
    
    weights = K.variable(weights)
        
    # scale predictions so that the class probas of each sample sum to 1
    y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
    # clip to prevent NaN's and Inf's
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # calc
    loss = y_true * K.log(y_pred) * weights
    loss = -K.sum(loss, -1)
    return loss

# %%
from functools import partial

# Weighted loss function to tackle class imbalance in the dataset

weights = np.array([float(len(y_train)) / float(list(y_train).count(0)), float(len(y_train)) / float(list(y_train).count(1)), float(len(y_train)) / float(list(y_train).count(2))])
w_cat_crossentropy = partial(weighted_categorical_crossentropy, weights = weights)
w_cat_crossentropy.__name__ = 'weighted_categorical_crossentropy'
        
balanced_accuracy = BalancedAccuracy(train_data = (X_train, y_train), validation_data = (X_test, y_test))
CALLBACKS = [balanced_accuracy]

# %%
#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[]))
print(X_train.shape)
# Out:
# (16556, 60)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Activation, BatchNormalization, Reshape
from keras.layers import Dropout
import tensorflow as tf 

model = Sequential()
#model.add(Reshape((X_train.shape[1], X_train.shape[2]), input_shape=(1, X_train.shape[1], X_train.shape[2])))
#model.add(Conv1D(32, 3, padding='same', input_shape=(X_train.shape[1], X_train.shape[2])))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
#print(model.output_shape)
#model.add(Flatten())
#model.add(GlobalAveragePooling1D())
#model.add(Dense(256, init='uniform'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
model.add(Dense(128, kernel_initializer="uniform", input_shape = (X_train.shape[1],)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation = 'softmax'))

adam = Adam(lr = 0.01)
y_train_one_hot = one_hot(y_train, 3)
y_test_one_hot = one_hot(y_test, 3)

model.compile(loss=w_cat_crossentropy, optimizer=adam, metrics=['accuracy'])

history = model.fit(X_train, y_train_one_hot, epochs=300, batch_size=512, validation_data=(X_test, y_test_one_hot), 
          verbose=2, shuffle=True, callbacks=CALLBACKS)
# Out:
# Train on 16556 samples, validate on 1393 samples
# Epoch 1/300
#  - 1s - loss: 2.9591 - acc: 0.5450 - val_loss: 5.5549 - val_acc: 0.5650
#
# Balanced Accuracy - val: 0.584
# Epoch 2/300
#  - 0s - loss: 2.2131 - acc: 0.6602 - val_loss: 5.3368 - val_acc: 0.6676
#
# Balanced Accuracy - val: 0.676
# Epoch 3/300
#  - 0s - loss: 2.0315 - acc: 0.6956 - val_loss: 5.4059 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.705
# Epoch 4/300
#  - 0s - loss: 1.8843 - acc: 0.7206 - val_loss: 5.0358 - val_acc: 0.5994
#
# Balanced Accuracy - val: 0.705
# Epoch 5/300
#  - 0s - loss: 1.8256 - acc: 0.7325 - val_loss: 4.9205 - val_acc: 0.6648
#
# Balanced Accuracy - val: 0.728
# Epoch 6/300
#  - 0s - loss: 1.7059 - acc: 0.7502 - val_loss: 4.9543 - val_acc: 0.6375
#
# Balanced Accuracy - val: 0.688
# Epoch 7/300
#  - 1s - loss: 1.6460 - acc: 0.7569 - val_loss: 5.0575 - val_acc: 0.6648
#
# Balanced Accuracy - val: 0.694
# Epoch 8/300
#  - 1s - loss: 1.6304 - acc: 0.7641 - val_loss: 5.3219 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.705
# Epoch 9/300
#  - 0s - loss: 1.5733 - acc: 0.7714 - val_loss: 5.1653 - val_acc: 0.6698
#
# Balanced Accuracy - val: 0.696
# Epoch 10/300
#  - 0s - loss: 1.5504 - acc: 0.7758 - val_loss: 5.2901 - val_acc: 0.6425
#
# Balanced Accuracy - val: 0.722
# Epoch 11/300
#  - 1s - loss: 1.5117 - acc: 0.7755 - val_loss: 5.7964 - val_acc: 0.6332
#
# Balanced Accuracy - val: 0.682
# Epoch 12/300
#  - 0s - loss: 1.5073 - acc: 0.7804 - val_loss: 4.9427 - val_acc: 0.6375
#
# Balanced Accuracy - val: 0.684
# Epoch 13/300
#  - 0s - loss: 1.4998 - acc: 0.7836 - val_loss: 5.3077 - val_acc: 0.6389
#
# Balanced Accuracy - val: 0.673
# Epoch 14/300
#  - 0s - loss: 1.4640 - acc: 0.7873 - val_loss: 5.3960 - val_acc: 0.6389
#
# Balanced Accuracy - val: 0.676
# Epoch 15/300
#  - 1s - loss: 1.4555 - acc: 0.7898 - val_loss: 5.1282 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.688
# Epoch 16/300
#  - 0s - loss: 1.4254 - acc: 0.7963 - val_loss: 5.0069 - val_acc: 0.6827
#
# Balanced Accuracy - val: 0.698
# Epoch 17/300
#  - 0s - loss: 1.4151 - acc: 0.7997 - val_loss: 5.0844 - val_acc: 0.6468
#
# Balanced Accuracy - val: 0.713
# Epoch 18/300
#  - 1s - loss: 1.4108 - acc: 0.7952 - val_loss: 5.7325 - val_acc: 0.6152
#
# Balanced Accuracy - val: 0.657
# Epoch 19/300
#  - 1s - loss: 1.3724 - acc: 0.8033 - val_loss: 5.6955 - val_acc: 0.6360
#
# Balanced Accuracy - val: 0.705
# Epoch 20/300
#  - 0s - loss: 1.3803 - acc: 0.8055 - val_loss: 4.7626 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.722
# Epoch 21/300
#  - 1s - loss: 1.3921 - acc: 0.8027 - val_loss: 5.2085 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.680
# Epoch 22/300
#  - 0s - loss: 1.3805 - acc: 0.8009 - val_loss: 5.6072 - val_acc: 0.6360
#
# Balanced Accuracy - val: 0.693
# Epoch 23/300
#  - 0s - loss: 1.3328 - acc: 0.8077 - val_loss: 5.7767 - val_acc: 0.6841
#
# Balanced Accuracy - val: 0.688
# Epoch 24/300
#  - 0s - loss: 1.3294 - acc: 0.8096 - val_loss: 5.7634 - val_acc: 0.6475
#
# Balanced Accuracy - val: 0.680
# Epoch 25/300
#  - 0s - loss: 1.3699 - acc: 0.8047 - val_loss: 5.4031 - val_acc: 0.6368
#
# Balanced Accuracy - val: 0.679
# Epoch 26/300
#  - 1s - loss: 1.3474 - acc: 0.8104 - val_loss: 5.5989 - val_acc: 0.6346
#
# Balanced Accuracy - val: 0.673
# Epoch 27/300
#  - 1s - loss: 1.3280 - acc: 0.8100 - val_loss: 5.7144 - val_acc: 0.6382
#
# Balanced Accuracy - val: 0.673
# Epoch 28/300
#  - 1s - loss: 1.2861 - acc: 0.8093 - val_loss: 5.8905 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.688
# Epoch 29/300
#  - 1s - loss: 1.2976 - acc: 0.8108 - val_loss: 5.9921 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.688
# Epoch 30/300
#  - 1s - loss: 1.2534 - acc: 0.8175 - val_loss: 6.1390 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.701
# Epoch 31/300
#  - 0s - loss: 1.3047 - acc: 0.8187 - val_loss: 5.8649 - val_acc: 0.6303
#
# Balanced Accuracy - val: 0.669
# Epoch 32/300
#  - 0s - loss: 1.2370 - acc: 0.8170 - val_loss: 5.6992 - val_acc: 0.6497
#
# Balanced Accuracy - val: 0.699
# Epoch 33/300
#  - 0s - loss: 1.2660 - acc: 0.8205 - val_loss: 6.5326 - val_acc: 0.6317
#
# Balanced Accuracy - val: 0.685
# Epoch 34/300
#  - 0s - loss: 1.2758 - acc: 0.8135 - val_loss: 5.9028 - val_acc: 0.6468
#
# Balanced Accuracy - val: 0.693
# Epoch 35/300
#  - 1s - loss: 1.2247 - acc: 0.8236 - val_loss: 6.0055 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.676
# Epoch 36/300
#  - 1s - loss: 1.2340 - acc: 0.8254 - val_loss: 6.0115 - val_acc: 0.6324
#
# Balanced Accuracy - val: 0.718
# Epoch 37/300
#  - 1s - loss: 1.2571 - acc: 0.8213 - val_loss: 5.8920 - val_acc: 0.6447
#
# Balanced Accuracy - val: 0.730
# Epoch 38/300
#  - 0s - loss: 1.2231 - acc: 0.8221 - val_loss: 6.5180 - val_acc: 0.6310
#
# Balanced Accuracy - val: 0.713
# Epoch 39/300
#  - 1s - loss: 1.2497 - acc: 0.8187 - val_loss: 6.2543 - val_acc: 0.6554
#
# Balanced Accuracy - val: 0.702
# Epoch 40/300
#  - 1s - loss: 1.2434 - acc: 0.8178 - val_loss: 5.9090 - val_acc: 0.6475
#
# Balanced Accuracy - val: 0.721
# Epoch 41/300
#  - 0s - loss: 1.2274 - acc: 0.8258 - val_loss: 5.7587 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.730
# Epoch 42/300
#  - 0s - loss: 1.2090 - acc: 0.8247 - val_loss: 6.3136 - val_acc: 0.6777
#
# Balanced Accuracy - val: 0.708
# Epoch 43/300
#  - 1s - loss: 1.1727 - acc: 0.8248 - val_loss: 6.1940 - val_acc: 0.6583
#
# Balanced Accuracy - val: 0.708
# Epoch 44/300
#  - 1s - loss: 1.2066 - acc: 0.8270 - val_loss: 6.5089 - val_acc: 0.6547
#
# Balanced Accuracy - val: 0.732
# Epoch 45/300
#  - 1s - loss: 1.2242 - acc: 0.8212 - val_loss: 5.7936 - val_acc: 0.6604
#
# Balanced Accuracy - val: 0.713
# Epoch 46/300
#  - 0s - loss: 1.2093 - acc: 0.8247 - val_loss: 6.1513 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.708
# Epoch 47/300
#  - 0s - loss: 1.2240 - acc: 0.8265 - val_loss: 6.0225 - val_acc: 0.6561
#
# Balanced Accuracy - val: 0.708
# Epoch 48/300
#  - 0s - loss: 1.2126 - acc: 0.8216 - val_loss: 6.4564 - val_acc: 0.6533
#
# Balanced Accuracy - val: 0.700
# Epoch 49/300
#  - 0s - loss: 1.2316 - acc: 0.8265 - val_loss: 6.3186 - val_acc: 0.6576
#
# Balanced Accuracy - val: 0.731
# Epoch 50/300
#  - 0s - loss: 1.2049 - acc: 0.8256 - val_loss: 6.2027 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.732
# Epoch 51/300
#  - 1s - loss: 1.1843 - acc: 0.8271 - val_loss: 6.2609 - val_acc: 0.6260
#
# Balanced Accuracy - val: 0.740
# Epoch 52/300
#  - 1s - loss: 1.1720 - acc: 0.8337 - val_loss: 6.8173 - val_acc: 0.6217
#
# Balanced Accuracy - val: 0.733
# Epoch 53/300
#  - 1s - loss: 1.1756 - acc: 0.8276 - val_loss: 6.7499 - val_acc: 0.6490
#
# Balanced Accuracy - val: 0.728
# Epoch 54/300
#  - 0s - loss: 1.1896 - acc: 0.8324 - val_loss: 6.6522 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.752
# Epoch 55/300
#  - 0s - loss: 1.2077 - acc: 0.8251 - val_loss: 6.6788 - val_acc: 0.6439
#
# Balanced Accuracy - val: 0.728
# Epoch 56/300
#  - 0s - loss: 1.1371 - acc: 0.8358 - val_loss: 6.6890 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.723
# Epoch 57/300
#  - 0s - loss: 1.1607 - acc: 0.8301 - val_loss: 6.3597 - val_acc: 0.6604
#
# Balanced Accuracy - val: 0.753
# Epoch 58/300
#  - 0s - loss: 1.1741 - acc: 0.8289 - val_loss: 6.7888 - val_acc: 0.6719
#
# Balanced Accuracy - val: 0.691
# Epoch 59/300
#  - 0s - loss: 1.1434 - acc: 0.8314 - val_loss: 6.5848 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.702
# Epoch 60/300
#  - 0s - loss: 1.1430 - acc: 0.8338 - val_loss: 6.6248 - val_acc: 0.6597
#
# Balanced Accuracy - val: 0.732
# Epoch 61/300
#  - 0s - loss: 1.1668 - acc: 0.8329 - val_loss: 6.6360 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.724
# Epoch 62/300
#  - 0s - loss: 1.1297 - acc: 0.8317 - val_loss: 7.3827 - val_acc: 0.6403
#
# Balanced Accuracy - val: 0.691
# Epoch 63/300
#  - 0s - loss: 1.1405 - acc: 0.8353 - val_loss: 7.1484 - val_acc: 0.6554
#
# Balanced Accuracy - val: 0.722
# Epoch 64/300
#  - 1s - loss: 1.1377 - acc: 0.8302 - val_loss: 6.9610 - val_acc: 0.6368
#
# Balanced Accuracy - val: 0.715
# Epoch 65/300
#  - 0s - loss: 1.1408 - acc: 0.8335 - val_loss: 7.3976 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.725
# Epoch 66/300
#  - 0s - loss: 1.1347 - acc: 0.8323 - val_loss: 7.4191 - val_acc: 0.6303
#
# Balanced Accuracy - val: 0.705
# Epoch 67/300
#  - 0s - loss: 1.1585 - acc: 0.8318 - val_loss: 6.7210 - val_acc: 0.6626
#
# Balanced Accuracy - val: 0.731
# Epoch 68/300
#  - 0s - loss: 1.1331 - acc: 0.8311 - val_loss: 7.7234 - val_acc: 0.6396
#
# Balanced Accuracy - val: 0.709
# Epoch 69/300
#  - 0s - loss: 1.1549 - acc: 0.8312 - val_loss: 7.9319 - val_acc: 0.6260
#
# Balanced Accuracy - val: 0.703
# Epoch 70/300
#  - 1s - loss: 1.1324 - acc: 0.8384 - val_loss: 7.0663 - val_acc: 0.6411
#
# Balanced Accuracy - val: 0.716
# Epoch 71/300
#  - 0s - loss: 1.1515 - acc: 0.8342 - val_loss: 6.9064 - val_acc: 0.6604
#
# Balanced Accuracy - val: 0.730
# Epoch 72/300
#  - 0s - loss: 1.1535 - acc: 0.8332 - val_loss: 6.6975 - val_acc: 0.6726
#
# Balanced Accuracy - val: 0.741
# Epoch 73/300
#  - 0s - loss: 1.1194 - acc: 0.8364 - val_loss: 7.7898 - val_acc: 0.6195
#
# Balanced Accuracy - val: 0.725
# Epoch 74/300
#  - 0s - loss: 1.1371 - acc: 0.8361 - val_loss: 7.2304 - val_acc: 0.6540
#
# Balanced Accuracy - val: 0.725
# Epoch 75/300
#  - 1s - loss: 1.0907 - acc: 0.8384 - val_loss: 7.2422 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.725
# Epoch 76/300
#  - 1s - loss: 1.1097 - acc: 0.8381 - val_loss: 6.9680 - val_acc: 0.6597
#
# Balanced Accuracy - val: 0.729
# Epoch 77/300
#  - 0s - loss: 1.1229 - acc: 0.8390 - val_loss: 7.2459 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.726
# Epoch 78/300
#  - 1s - loss: 1.1038 - acc: 0.8414 - val_loss: 7.2141 - val_acc: 0.6583
#
# Balanced Accuracy - val: 0.721
# Epoch 79/300
#  - 1s - loss: 1.1252 - acc: 0.8331 - val_loss: 6.9904 - val_acc: 0.6432
#
# Balanced Accuracy - val: 0.746
# Epoch 80/300
#  - 0s - loss: 1.1087 - acc: 0.8410 - val_loss: 6.9926 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.733
# Epoch 81/300
#  - 0s - loss: 1.1015 - acc: 0.8396 - val_loss: 7.2374 - val_acc: 0.6389
#
# Balanced Accuracy - val: 0.714
# Epoch 82/300
#  - 1s - loss: 1.1180 - acc: 0.8402 - val_loss: 6.9362 - val_acc: 0.6640
#
# Balanced Accuracy - val: 0.724
# Epoch 83/300
#  - 0s - loss: 1.1084 - acc: 0.8381 - val_loss: 7.4133 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.720
# Epoch 84/300
#  - 0s - loss: 1.1171 - acc: 0.8369 - val_loss: 7.3233 - val_acc: 0.6597
#
# Balanced Accuracy - val: 0.728
# Epoch 85/300
#  - 1s - loss: 1.1101 - acc: 0.8358 - val_loss: 7.6908 - val_acc: 0.6375
#
# Balanced Accuracy - val: 0.713
# Epoch 86/300
#  - 1s - loss: 1.1221 - acc: 0.8363 - val_loss: 7.2792 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.703
# Epoch 87/300
#  - 1s - loss: 1.1464 - acc: 0.8344 - val_loss: 7.3236 - val_acc: 0.6468
#
# Balanced Accuracy - val: 0.728
# Epoch 88/300
#  - 0s - loss: 1.1027 - acc: 0.8409 - val_loss: 7.6904 - val_acc: 0.6432
#
# Balanced Accuracy - val: 0.726
# Epoch 89/300
#  - 1s - loss: 1.1060 - acc: 0.8379 - val_loss: 7.5564 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.736
# Epoch 90/300
#  - 0s - loss: 1.0994 - acc: 0.8410 - val_loss: 7.3165 - val_acc: 0.6971
#
# Balanced Accuracy - val: 0.746
# Epoch 91/300
#  - 1s - loss: 1.0692 - acc: 0.8401 - val_loss: 7.3846 - val_acc: 0.6346
#
# Balanced Accuracy - val: 0.713
# Epoch 92/300
#  - 0s - loss: 1.0888 - acc: 0.8412 - val_loss: 7.2157 - val_acc: 0.6518
#
# Balanced Accuracy - val: 0.725
# Epoch 93/300
#  - 0s - loss: 1.0889 - acc: 0.8407 - val_loss: 7.7844 - val_acc: 0.6461
#
# Balanced Accuracy - val: 0.714
# Epoch 94/300
#  - 0s - loss: 1.0729 - acc: 0.8408 - val_loss: 7.3620 - val_acc: 0.6612
#
# Balanced Accuracy - val: 0.732
# Epoch 95/300
#  - 0s - loss: 1.0726 - acc: 0.8404 - val_loss: 7.6150 - val_acc: 0.6784
#
# Balanced Accuracy - val: 0.733
# Epoch 96/300
#  - 0s - loss: 1.1000 - acc: 0.8403 - val_loss: 7.4756 - val_acc: 0.6662
#
# Balanced Accuracy - val: 0.732
# Epoch 97/300
#  - 0s - loss: 1.0565 - acc: 0.8426 - val_loss: 7.4471 - val_acc: 0.6497
#
# Balanced Accuracy - val: 0.725
# Epoch 98/300
#  - 0s - loss: 1.0592 - acc: 0.8428 - val_loss: 7.6462 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.728
# Epoch 99/300
#  - 0s - loss: 1.0752 - acc: 0.8427 - val_loss: 7.6199 - val_acc: 0.6648
#
# Balanced Accuracy - val: 0.731
# Epoch 100/300
#  - 0s - loss: 1.0972 - acc: 0.8439 - val_loss: 7.1531 - val_acc: 0.6468
#
# Balanced Accuracy - val: 0.747
# Epoch 101/300
#  - 0s - loss: 1.0547 - acc: 0.8433 - val_loss: 7.9805 - val_acc: 0.6633
#
# Balanced Accuracy - val: 0.728
# Epoch 102/300
#  - 0s - loss: 1.0622 - acc: 0.8442 - val_loss: 7.6033 - val_acc: 0.6411
#
# Balanced Accuracy - val: 0.715
# Epoch 103/300
#  - 1s - loss: 1.0617 - acc: 0.8405 - val_loss: 7.7682 - val_acc: 0.6676
#
# Balanced Accuracy - val: 0.729
# Epoch 104/300
#  - 1s - loss: 1.0635 - acc: 0.8450 - val_loss: 7.8879 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.698
# Epoch 105/300
#  - 1s - loss: 1.1042 - acc: 0.8414 - val_loss: 7.3439 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.713
# Epoch 106/300
#  - 0s - loss: 1.0260 - acc: 0.8439 - val_loss: 7.8834 - val_acc: 0.6576
#
# Balanced Accuracy - val: 0.752
# Epoch 107/300
#  - 0s - loss: 1.0698 - acc: 0.8411 - val_loss: 8.2371 - val_acc: 0.6856
#
# Balanced Accuracy - val: 0.737
# Epoch 108/300
#  - 0s - loss: 1.0837 - acc: 0.8373 - val_loss: 7.4798 - val_acc: 0.6310
#
# Balanced Accuracy - val: 0.764
# Epoch 109/300
#  - 1s - loss: 1.0501 - acc: 0.8480 - val_loss: 7.2836 - val_acc: 0.6468
#
# Balanced Accuracy - val: 0.739
# Epoch 110/300
#  - 0s - loss: 1.1095 - acc: 0.8386 - val_loss: 8.0835 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.738
# Epoch 111/300
#  - 0s - loss: 1.0717 - acc: 0.8422 - val_loss: 8.5065 - val_acc: 0.6217
#
# Balanced Accuracy - val: 0.713
# Epoch 112/300
#  - 0s - loss: 1.0620 - acc: 0.8462 - val_loss: 8.6129 - val_acc: 0.6281
#
# Balanced Accuracy - val: 0.711
# Epoch 113/300
#  - 0s - loss: 1.0625 - acc: 0.8483 - val_loss: 7.9354 - val_acc: 0.6676
#
# Balanced Accuracy - val: 0.730
# Epoch 114/300
#  - 1s - loss: 1.0613 - acc: 0.8465 - val_loss: 7.7011 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.735
# Epoch 115/300
#  - 0s - loss: 1.0576 - acc: 0.8454 - val_loss: 7.3611 - val_acc: 0.6640
#
# Balanced Accuracy - val: 0.756
# Epoch 116/300
#  - 0s - loss: 1.0707 - acc: 0.8451 - val_loss: 7.2556 - val_acc: 0.6777
#
# Balanced Accuracy - val: 0.766
# Epoch 117/300
#  - 0s - loss: 1.0568 - acc: 0.8478 - val_loss: 8.4512 - val_acc: 0.6504
#
# Balanced Accuracy - val: 0.719
# Epoch 118/300
#  - 0s - loss: 1.0616 - acc: 0.8457 - val_loss: 7.7692 - val_acc: 0.6777
#
# Balanced Accuracy - val: 0.743
# Epoch 119/300
#  - 1s - loss: 1.0393 - acc: 0.8452 - val_loss: 8.2073 - val_acc: 0.6411
#
# Balanced Accuracy - val: 0.719
# Epoch 120/300
#  - 1s - loss: 1.0689 - acc: 0.8462 - val_loss: 7.1215 - val_acc: 0.6770
#
# Balanced Accuracy - val: 0.737
# Epoch 121/300
#  - 1s - loss: 1.0780 - acc: 0.8420 - val_loss: 7.6820 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.748
# Epoch 122/300
#  - 0s - loss: 1.0532 - acc: 0.8447 - val_loss: 7.4705 - val_acc: 0.6518
#
# Balanced Accuracy - val: 0.728
# Epoch 123/300
#  - 0s - loss: 1.0528 - acc: 0.8456 - val_loss: 7.2925 - val_acc: 0.6604
#
# Balanced Accuracy - val: 0.772
# Epoch 124/300
#  - 0s - loss: 1.0567 - acc: 0.8450 - val_loss: 7.9452 - val_acc: 0.6583
#
# Balanced Accuracy - val: 0.752
# Epoch 125/300
#  - 0s - loss: 1.0337 - acc: 0.8456 - val_loss: 7.4579 - val_acc: 0.6863
#
# Balanced Accuracy - val: 0.767
# Epoch 126/300
#  - 1s - loss: 1.0608 - acc: 0.8433 - val_loss: 8.1064 - val_acc: 0.6935
#
# Balanced Accuracy - val: 0.737
# Epoch 127/300
#  - 1s - loss: 1.0326 - acc: 0.8460 - val_loss: 8.6885 - val_acc: 0.6554
#
# Balanced Accuracy - val: 0.768
# Epoch 128/300
#  - 0s - loss: 1.0403 - acc: 0.8488 - val_loss: 8.1358 - val_acc: 0.6317
#
# Balanced Accuracy - val: 0.760
# Epoch 129/300
#  - 0s - loss: 1.0169 - acc: 0.8489 - val_loss: 7.5996 - val_acc: 0.6540
#
# Balanced Accuracy - val: 0.747
# Epoch 130/300
#  - 0s - loss: 1.0416 - acc: 0.8446 - val_loss: 8.1078 - val_acc: 0.6841
#
# Balanced Accuracy - val: 0.740
# Epoch 131/300
#  - 0s - loss: 1.0129 - acc: 0.8472 - val_loss: 8.0026 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.738
# Epoch 132/300
#  - 0s - loss: 1.0377 - acc: 0.8434 - val_loss: 8.4542 - val_acc: 0.6368
#
# Balanced Accuracy - val: 0.736
# Epoch 133/300
#  - 0s - loss: 1.0261 - acc: 0.8473 - val_loss: 8.2344 - val_acc: 0.6533
#
# Balanced Accuracy - val: 0.691
# Epoch 134/300
#  - 0s - loss: 1.0335 - acc: 0.8478 - val_loss: 8.5043 - val_acc: 0.6382
#
# Balanced Accuracy - val: 0.684
# Epoch 135/300
#  - 1s - loss: 1.0352 - acc: 0.8459 - val_loss: 7.5848 - val_acc: 0.6849
#
# Balanced Accuracy - val: 0.731
# Epoch 136/300
#  - 0s - loss: 1.0231 - acc: 0.8471 - val_loss: 8.5422 - val_acc: 0.6705
#
# Balanced Accuracy - val: 0.725
# Epoch 137/300
#  - 1s - loss: 1.0491 - acc: 0.8461 - val_loss: 7.8658 - val_acc: 0.7035
#
# Balanced Accuracy - val: 0.762
# Epoch 138/300
#  - 0s - loss: 1.0537 - acc: 0.8475 - val_loss: 8.1644 - val_acc: 0.6597
#
# Balanced Accuracy - val: 0.719
# Epoch 139/300
#  - 1s - loss: 1.0555 - acc: 0.8469 - val_loss: 7.5259 - val_acc: 0.6791
#
# Balanced Accuracy - val: 0.734
# Epoch 140/300
#  - 1s - loss: 1.0321 - acc: 0.8497 - val_loss: 8.8232 - val_acc: 0.6547
#
# Balanced Accuracy - val: 0.716
# Epoch 141/300
#  - 1s - loss: 1.0423 - acc: 0.8436 - val_loss: 8.0679 - val_acc: 0.6770
#
# Balanced Accuracy - val: 0.753
# Epoch 142/300
#  - 0s - loss: 1.0423 - acc: 0.8456 - val_loss: 8.1581 - val_acc: 0.6877
#
# Balanced Accuracy - val: 0.784
# Epoch 143/300
#  - 1s - loss: 1.0241 - acc: 0.8514 - val_loss: 7.9918 - val_acc: 0.6583
#
# Balanced Accuracy - val: 0.768
# Epoch 144/300
#  - 1s - loss: 1.0218 - acc: 0.8491 - val_loss: 8.0007 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.752
# Epoch 145/300
#  - 1s - loss: 1.0227 - acc: 0.8509 - val_loss: 8.0844 - val_acc: 0.6762
#
# Balanced Accuracy - val: 0.752
# Epoch 146/300
#  - 1s - loss: 1.0185 - acc: 0.8512 - val_loss: 8.2802 - val_acc: 0.6827
#
# Balanced Accuracy - val: 0.758
# Epoch 147/300
#  - 0s - loss: 1.0106 - acc: 0.8459 - val_loss: 7.8962 - val_acc: 0.6619
#
# Balanced Accuracy - val: 0.750
# Epoch 148/300
#  - 0s - loss: 1.0232 - acc: 0.8481 - val_loss: 8.4599 - val_acc: 0.6554
#
# Balanced Accuracy - val: 0.746
# Epoch 149/300
#  - 0s - loss: 1.0232 - acc: 0.8499 - val_loss: 7.9751 - val_acc: 0.6518
#
# Balanced Accuracy - val: 0.718
# Epoch 150/300
#  - 0s - loss: 1.0283 - acc: 0.8491 - val_loss: 7.7273 - val_acc: 0.6813
#
# Balanced Accuracy - val: 0.732
# Epoch 151/300
#  - 0s - loss: 1.0435 - acc: 0.8481 - val_loss: 7.8028 - val_acc: 0.6920
#
# Balanced Accuracy - val: 0.762
# Epoch 152/300
#  - 0s - loss: 1.0115 - acc: 0.8515 - val_loss: 8.6291 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.736
# Epoch 153/300
#  - 1s - loss: 0.9998 - acc: 0.8486 - val_loss: 8.9514 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.740
# Epoch 154/300
#  - 0s - loss: 1.0236 - acc: 0.8523 - val_loss: 8.2988 - val_acc: 0.6518
#
# Balanced Accuracy - val: 0.712
# Epoch 155/300
#  - 0s - loss: 1.0172 - acc: 0.8447 - val_loss: 8.9595 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.716
# Epoch 156/300
#  - 0s - loss: 1.0424 - acc: 0.8450 - val_loss: 8.6356 - val_acc: 0.6662
#
# Balanced Accuracy - val: 0.746
# Epoch 157/300
#  - 0s - loss: 1.0166 - acc: 0.8474 - val_loss: 8.8033 - val_acc: 0.7014
#
# Balanced Accuracy - val: 0.744
# Epoch 158/300
#  - 0s - loss: 1.0277 - acc: 0.8507 - val_loss: 7.9793 - val_acc: 0.6899
#
# Balanced Accuracy - val: 0.739
# Epoch 159/300
#  - 1s - loss: 1.0287 - acc: 0.8431 - val_loss: 8.4787 - val_acc: 0.6762
#
# Balanced Accuracy - val: 0.731
# Epoch 160/300
#  - 0s - loss: 1.0079 - acc: 0.8504 - val_loss: 8.7515 - val_acc: 0.6439
#
# Balanced Accuracy - val: 0.712
# Epoch 161/300
#  - 0s - loss: 0.9983 - acc: 0.8496 - val_loss: 9.0627 - val_acc: 0.6403
#
# Balanced Accuracy - val: 0.712
# Epoch 162/300
#  - 0s - loss: 1.0434 - acc: 0.8473 - val_loss: 8.8153 - val_acc: 0.6576
#
# Balanced Accuracy - val: 0.722
# Epoch 163/300
#  - 0s - loss: 1.0254 - acc: 0.8492 - val_loss: 8.5908 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.732
# Epoch 164/300
#  - 0s - loss: 1.0177 - acc: 0.8465 - val_loss: 9.4044 - val_acc: 0.6202
#
# Balanced Accuracy - val: 0.729
# Epoch 165/300
#  - 0s - loss: 1.0041 - acc: 0.8525 - val_loss: 8.6886 - val_acc: 0.6310
#
# Balanced Accuracy - val: 0.732
# Epoch 166/300
#  - 0s - loss: 1.0003 - acc: 0.8500 - val_loss: 8.7214 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.713
# Epoch 167/300
#  - 0s - loss: 1.0145 - acc: 0.8492 - val_loss: 9.0517 - val_acc: 0.6540
#
# Balanced Accuracy - val: 0.733
# Epoch 168/300
#  - 0s - loss: 1.0207 - acc: 0.8497 - val_loss: 8.6859 - val_acc: 0.6755
#
# Balanced Accuracy - val: 0.731
# Epoch 169/300
#  - 1s - loss: 1.0173 - acc: 0.8485 - val_loss: 8.5586 - val_acc: 0.6662
#
# Balanced Accuracy - val: 0.720
# Epoch 170/300
#  - 1s - loss: 1.0419 - acc: 0.8495 - val_loss: 8.7364 - val_acc: 0.6590
#
# Balanced Accuracy - val: 0.717
# Epoch 171/300
#  - 1s - loss: 0.9999 - acc: 0.8521 - val_loss: 8.5393 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.720
# Epoch 172/300
#  - 1s - loss: 1.0023 - acc: 0.8482 - val_loss: 8.5466 - val_acc: 0.6619
#
# Balanced Accuracy - val: 0.716
# Epoch 173/300
#  - 1s - loss: 0.9847 - acc: 0.8499 - val_loss: 8.4841 - val_acc: 0.6454
#
# Balanced Accuracy - val: 0.708
# Epoch 174/300
#  - 0s - loss: 1.0055 - acc: 0.8517 - val_loss: 8.5482 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.725
# Epoch 175/300
#  - 0s - loss: 1.0159 - acc: 0.8507 - val_loss: 8.7931 - val_acc: 0.6576
#
# Balanced Accuracy - val: 0.732
# Epoch 176/300
#  - 0s - loss: 1.0201 - acc: 0.8496 - val_loss: 8.7150 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.748
# Epoch 177/300
#  - 0s - loss: 1.0030 - acc: 0.8504 - val_loss: 9.0381 - val_acc: 0.6418
#
# Balanced Accuracy - val: 0.731
# Epoch 178/300
#  - 0s - loss: 0.9986 - acc: 0.8502 - val_loss: 9.6209 - val_acc: 0.6447
#
# Balanced Accuracy - val: 0.728
# Epoch 179/300
#  - 0s - loss: 1.0342 - acc: 0.8477 - val_loss: 8.8673 - val_acc: 0.6949
#
# Balanced Accuracy - val: 0.738
# Epoch 180/300
#  - 1s - loss: 1.0032 - acc: 0.8530 - val_loss: 8.3515 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.708
# Epoch 181/300
#  - 0s - loss: 1.0035 - acc: 0.8532 - val_loss: 9.0208 - val_acc: 0.6619
#
# Balanced Accuracy - val: 0.720
# Epoch 182/300
#  - 0s - loss: 0.9746 - acc: 0.8550 - val_loss: 9.2689 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.716
# Epoch 183/300
#  - 0s - loss: 1.0351 - acc: 0.8508 - val_loss: 8.4366 - val_acc: 0.6906
#
# Balanced Accuracy - val: 0.735
# Epoch 184/300
#  - 1s - loss: 1.0203 - acc: 0.8510 - val_loss: 9.0924 - val_acc: 0.6497
#
# Balanced Accuracy - val: 0.714
# Epoch 185/300
#  - 0s - loss: 0.9898 - acc: 0.8522 - val_loss: 8.8327 - val_acc: 0.6691
#
# Balanced Accuracy - val: 0.719
# Epoch 186/300
#  - 0s - loss: 0.9847 - acc: 0.8570 - val_loss: 9.2314 - val_acc: 0.6432
#
# Balanced Accuracy - val: 0.714
# Epoch 187/300
#  - 1s - loss: 1.0099 - acc: 0.8474 - val_loss: 8.9520 - val_acc: 0.6612
#
# Balanced Accuracy - val: 0.743
# Epoch 188/300
#  - 1s - loss: 1.0114 - acc: 0.8494 - val_loss: 9.5446 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.715
# Epoch 189/300
#  - 1s - loss: 1.0267 - acc: 0.8530 - val_loss: 8.5595 - val_acc: 0.6633
#
# Balanced Accuracy - val: 0.724
# Epoch 190/300
#  - 1s - loss: 1.0012 - acc: 0.8498 - val_loss: 9.3491 - val_acc: 0.6698
#
# Balanced Accuracy - val: 0.751
# Epoch 191/300
#  - 0s - loss: 0.9872 - acc: 0.8528 - val_loss: 9.7849 - val_acc: 0.6475
#
# Balanced Accuracy - val: 0.715
# Epoch 192/300
#  - 0s - loss: 1.0328 - acc: 0.8502 - val_loss: 10.0031 - val_acc: 0.6475
#
# Balanced Accuracy - val: 0.717
# Epoch 193/300
#  - 1s - loss: 0.9888 - acc: 0.8544 - val_loss: 9.8502 - val_acc: 0.6490
#
# Balanced Accuracy - val: 0.711
# Epoch 194/300
#  - 0s - loss: 1.0054 - acc: 0.8475 - val_loss: 10.1191 - val_acc: 0.6396
#
# Balanced Accuracy - val: 0.706
# Epoch 195/300
#  - 1s - loss: 0.9920 - acc: 0.8554 - val_loss: 9.4521 - val_acc: 0.6267
#
# Balanced Accuracy - val: 0.698
# Epoch 196/300
#  - 0s - loss: 0.9949 - acc: 0.8517 - val_loss: 8.9094 - val_acc: 0.6942
#
# Balanced Accuracy - val: 0.736
# Epoch 197/300
#  - 1s - loss: 1.0088 - acc: 0.8507 - val_loss: 8.9721 - val_acc: 0.6777
#
# Balanced Accuracy - val: 0.727
# Epoch 198/300
#  - 0s - loss: 0.9738 - acc: 0.8552 - val_loss: 9.5267 - val_acc: 0.6841
#
# Balanced Accuracy - val: 0.753
# Epoch 199/300
#  - 0s - loss: 0.9555 - acc: 0.8565 - val_loss: 9.2169 - val_acc: 0.6698
#
# Balanced Accuracy - val: 0.744
# Epoch 200/300
#  - 0s - loss: 1.0037 - acc: 0.8483 - val_loss: 8.9269 - val_acc: 0.6841
#
# Balanced Accuracy - val: 0.727
# Epoch 201/300
#  - 0s - loss: 0.9893 - acc: 0.8519 - val_loss: 9.5308 - val_acc: 0.6762
#
# Balanced Accuracy - val: 0.724
# Epoch 202/300
#  - 0s - loss: 0.9808 - acc: 0.8505 - val_loss: 8.9508 - val_acc: 0.6748
#
# Balanced Accuracy - val: 0.717
# Epoch 203/300
#  - 0s - loss: 0.9753 - acc: 0.8536 - val_loss: 9.2520 - val_acc: 0.6884
#
# Balanced Accuracy - val: 0.704
# Epoch 204/300
#  - 0s - loss: 0.9760 - acc: 0.8518 - val_loss: 10.1579 - val_acc: 0.6820
#
# Balanced Accuracy - val: 0.700
# Epoch 205/300
#  - 0s - loss: 0.9860 - acc: 0.8565 - val_loss: 9.0367 - val_acc: 0.6963
#
# Balanced Accuracy - val: 0.710
# Epoch 206/300
#  - 0s - loss: 0.9605 - acc: 0.8534 - val_loss: 9.0950 - val_acc: 0.7021
#
# Balanced Accuracy - val: 0.716
# Epoch 207/300
#  - 1s - loss: 0.9519 - acc: 0.8556 - val_loss: 8.9872 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.727
# Epoch 208/300
#  - 1s - loss: 0.9852 - acc: 0.8552 - val_loss: 9.1352 - val_acc: 0.6949
#
# Balanced Accuracy - val: 0.734
# Epoch 209/300
#  - 0s - loss: 0.9823 - acc: 0.8587 - val_loss: 9.1375 - val_acc: 0.6561
#
# Balanced Accuracy - val: 0.742
# Epoch 210/300
#  - 0s - loss: 1.0110 - acc: 0.8502 - val_loss: 9.9318 - val_acc: 0.6698
#
# Balanced Accuracy - val: 0.716
# Epoch 211/300
#  - 0s - loss: 0.9796 - acc: 0.8540 - val_loss: 8.8884 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.739
# Epoch 212/300
#  - 0s - loss: 1.0081 - acc: 0.8541 - val_loss: 9.5298 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.751
# Epoch 213/300
#  - 0s - loss: 0.9829 - acc: 0.8517 - val_loss: 9.8522 - val_acc: 0.6676
#
# Balanced Accuracy - val: 0.720
# Epoch 214/300
#  - 0s - loss: 0.9543 - acc: 0.8571 - val_loss: 9.0597 - val_acc: 0.6863
#
# Balanced Accuracy - val: 0.758
# Epoch 215/300
#  - 0s - loss: 0.9659 - acc: 0.8547 - val_loss: 8.9594 - val_acc: 0.7006
#
# Balanced Accuracy - val: 0.718
# Epoch 216/300
#  - 0s - loss: 1.0260 - acc: 0.8483 - val_loss: 9.2960 - val_acc: 0.6396
#
# Balanced Accuracy - val: 0.732
# Epoch 217/300
#  - 1s - loss: 0.9990 - acc: 0.8530 - val_loss: 9.2064 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.735
# Epoch 218/300
#  - 0s - loss: 1.0261 - acc: 0.8508 - val_loss: 10.0411 - val_acc: 0.6554
#
# Balanced Accuracy - val: 0.717
# Epoch 219/300
#  - 0s - loss: 0.9894 - acc: 0.8553 - val_loss: 9.7205 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.745
# Epoch 220/300
#  - 0s - loss: 0.9963 - acc: 0.8520 - val_loss: 9.5004 - val_acc: 0.6741
#
# Balanced Accuracy - val: 0.721
# Epoch 221/300
#  - 0s - loss: 1.0030 - acc: 0.8523 - val_loss: 9.1708 - val_acc: 0.6648
#
# Balanced Accuracy - val: 0.745
# Epoch 222/300
#  - 1s - loss: 0.9604 - acc: 0.8585 - val_loss: 9.6089 - val_acc: 0.6719
#
# Balanced Accuracy - val: 0.746
# Epoch 223/300
#  - 1s - loss: 1.0162 - acc: 0.8500 - val_loss: 9.8792 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.709
# Epoch 224/300
#  - 0s - loss: 0.9872 - acc: 0.8524 - val_loss: 10.2424 - val_acc: 0.6504
#
# Balanced Accuracy - val: 0.709
# Epoch 225/300
#  - 0s - loss: 0.9778 - acc: 0.8573 - val_loss: 10.0942 - val_acc: 0.6770
#
# Balanced Accuracy - val: 0.748
# Epoch 226/300
#  - 1s - loss: 0.9844 - acc: 0.8531 - val_loss: 10.4430 - val_acc: 0.6705
#
# Balanced Accuracy - val: 0.746
# Epoch 227/300
#  - 1s - loss: 1.0099 - acc: 0.8502 - val_loss: 9.5246 - val_acc: 0.6777
#
# Balanced Accuracy - val: 0.755
# Epoch 228/300
#  - 0s - loss: 1.0069 - acc: 0.8568 - val_loss: 9.7571 - val_acc: 0.6719
#
# Balanced Accuracy - val: 0.749
# Epoch 229/300
#  - 0s - loss: 1.0254 - acc: 0.8517 - val_loss: 9.7341 - val_acc: 0.6798
#
# Balanced Accuracy - val: 0.750
# Epoch 230/300
#  - 0s - loss: 1.0035 - acc: 0.8525 - val_loss: 9.7810 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.748
# Epoch 231/300
#  - 0s - loss: 0.9971 - acc: 0.8518 - val_loss: 9.8045 - val_acc: 0.6892
#
# Balanced Accuracy - val: 0.760
# Epoch 232/300
#  - 0s - loss: 1.0298 - acc: 0.8511 - val_loss: 10.6458 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.733
# Epoch 233/300
#  - 0s - loss: 0.9774 - acc: 0.8517 - val_loss: 10.7419 - val_acc: 0.6698
#
# Balanced Accuracy - val: 0.745
# Epoch 234/300
#  - 0s - loss: 1.0049 - acc: 0.8512 - val_loss: 9.5993 - val_acc: 0.6827
#
# Balanced Accuracy - val: 0.756
# Epoch 235/300
#  - 1s - loss: 0.9639 - acc: 0.8575 - val_loss: 9.8066 - val_acc: 0.6691
#
# Balanced Accuracy - val: 0.740
# Epoch 236/300
#  - 0s - loss: 0.9877 - acc: 0.8579 - val_loss: 9.4879 - val_acc: 0.6770
#
# Balanced Accuracy - val: 0.749
# Epoch 237/300
#  - 0s - loss: 0.9762 - acc: 0.8581 - val_loss: 9.0154 - val_acc: 0.7050
#
# Balanced Accuracy - val: 0.740
# Epoch 238/300
#  - 0s - loss: 0.9758 - acc: 0.8543 - val_loss: 10.1113 - val_acc: 0.6863
#
# Balanced Accuracy - val: 0.732
# Epoch 239/300
#  - 0s - loss: 1.0100 - acc: 0.8537 - val_loss: 9.8754 - val_acc: 0.6856
#
# Balanced Accuracy - val: 0.731
# Epoch 240/300
#  - 0s - loss: 0.9815 - acc: 0.8554 - val_loss: 10.2223 - val_acc: 0.6827
#
# Balanced Accuracy - val: 0.730
# Epoch 241/300
#  - 0s - loss: 0.9765 - acc: 0.8538 - val_loss: 9.9876 - val_acc: 0.6963
#
# Balanced Accuracy - val: 0.737
# Epoch 242/300
#  - 1s - loss: 0.9592 - acc: 0.8572 - val_loss: 10.4373 - val_acc: 0.6683
#
# Balanced Accuracy - val: 0.738
# Epoch 243/300
#  - 1s - loss: 0.9764 - acc: 0.8559 - val_loss: 9.2249 - val_acc: 0.6612
#
# Balanced Accuracy - val: 0.742
# Epoch 244/300
#  - 0s - loss: 0.9691 - acc: 0.8498 - val_loss: 10.2093 - val_acc: 0.6813
#
# Balanced Accuracy - val: 0.726
# Epoch 245/300
#  - 0s - loss: 0.9447 - acc: 0.8569 - val_loss: 10.2014 - val_acc: 0.6612
#
# Balanced Accuracy - val: 0.739
# Epoch 246/300
#  - 0s - loss: 0.9887 - acc: 0.8544 - val_loss: 10.0199 - val_acc: 0.6475
#
# Balanced Accuracy - val: 0.733
# Epoch 247/300
#  - 0s - loss: 0.9665 - acc: 0.8519 - val_loss: 9.5673 - val_acc: 0.6583
#
# Balanced Accuracy - val: 0.715
# Epoch 248/300
#  - 1s - loss: 0.9706 - acc: 0.8596 - val_loss: 9.9769 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.734
# Epoch 249/300
#  - 0s - loss: 0.9776 - acc: 0.8538 - val_loss: 9.5845 - val_acc: 0.6849
#
# Balanced Accuracy - val: 0.726
# Epoch 250/300
#  - 0s - loss: 0.9739 - acc: 0.8533 - val_loss: 9.9902 - val_acc: 0.6705
#
# Balanced Accuracy - val: 0.745
# Epoch 251/300
#  - 0s - loss: 0.9713 - acc: 0.8541 - val_loss: 10.0909 - val_acc: 0.6604
#
# Balanced Accuracy - val: 0.736
# Epoch 252/300
#  - 0s - loss: 0.9776 - acc: 0.8561 - val_loss: 10.0146 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.748
# Epoch 253/300
#  - 0s - loss: 0.9794 - acc: 0.8558 - val_loss: 9.4103 - val_acc: 0.6683
#
# Balanced Accuracy - val: 0.743
# Epoch 254/300
#  - 0s - loss: 0.9738 - acc: 0.8552 - val_loss: 10.3326 - val_acc: 0.6669
#
# Balanced Accuracy - val: 0.744
# Epoch 255/300
#  - 0s - loss: 0.9635 - acc: 0.8586 - val_loss: 9.9433 - val_acc: 0.6834
#
# Balanced Accuracy - val: 0.753
# Epoch 256/300
#  - 0s - loss: 0.9463 - acc: 0.8584 - val_loss: 9.4822 - val_acc: 0.7035
#
# Balanced Accuracy - val: 0.766
# Epoch 257/300
#  - 0s - loss: 0.9550 - acc: 0.8534 - val_loss: 10.4339 - val_acc: 0.6963
#
# Balanced Accuracy - val: 0.758
# Epoch 258/300
#  - 0s - loss: 0.9691 - acc: 0.8559 - val_loss: 10.6315 - val_acc: 0.6662
#
# Balanced Accuracy - val: 0.740
# Epoch 259/300
#  - 0s - loss: 0.9731 - acc: 0.8579 - val_loss: 10.4189 - val_acc: 0.6755
#
# Balanced Accuracy - val: 0.747
# Epoch 260/300
#  - 0s - loss: 0.9434 - acc: 0.8545 - val_loss: 9.6813 - val_acc: 0.6906
#
# Balanced Accuracy - val: 0.762
# Epoch 261/300
#  - 1s - loss: 0.9562 - acc: 0.8544 - val_loss: 10.1111 - val_acc: 0.6511
#
# Balanced Accuracy - val: 0.732
# Epoch 262/300
#  - 1s - loss: 0.9592 - acc: 0.8556 - val_loss: 10.7763 - val_acc: 0.6411
#
# Balanced Accuracy - val: 0.720
# Epoch 263/300
#  - 1s - loss: 0.9474 - acc: 0.8619 - val_loss: 10.1629 - val_acc: 0.6942
#
# Balanced Accuracy - val: 0.756
# Epoch 264/300
#  - 0s - loss: 0.9665 - acc: 0.8561 - val_loss: 10.9879 - val_acc: 0.6626
#
# Balanced Accuracy - val: 0.735
# Epoch 265/300
#  - 1s - loss: 0.9339 - acc: 0.8613 - val_loss: 10.4128 - val_acc: 0.6877
#
# Balanced Accuracy - val: 0.757
# Epoch 266/300
#  - 0s - loss: 0.9654 - acc: 0.8604 - val_loss: 10.6143 - val_acc: 0.6827
#
# Balanced Accuracy - val: 0.729
# Epoch 267/300
#  - 0s - loss: 0.9251 - acc: 0.8588 - val_loss: 10.9234 - val_acc: 0.6296
#
# Balanced Accuracy - val: 0.722
# Epoch 268/300
#  - 0s - loss: 0.9788 - acc: 0.8631 - val_loss: 10.5086 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.750
# Epoch 269/300
#  - 1s - loss: 0.9738 - acc: 0.8567 - val_loss: 9.1912 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.756
# Epoch 270/300
#  - 0s - loss: 0.9470 - acc: 0.8577 - val_loss: 9.7429 - val_acc: 0.6741
#
# Balanced Accuracy - val: 0.751
# Epoch 271/300
#  - 0s - loss: 0.9936 - acc: 0.8587 - val_loss: 9.8189 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.745
# Epoch 272/300
#  - 1s - loss: 0.9437 - acc: 0.8591 - val_loss: 10.3236 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.709
# Epoch 273/300
#  - 1s - loss: 0.9975 - acc: 0.8565 - val_loss: 9.2952 - val_acc: 0.6863
#
# Balanced Accuracy - val: 0.757
# Epoch 274/300
#  - 1s - loss: 0.9781 - acc: 0.8567 - val_loss: 10.1967 - val_acc: 0.6741
#
# Balanced Accuracy - val: 0.719
# Epoch 275/300
#  - 1s - loss: 0.9585 - acc: 0.8593 - val_loss: 9.4758 - val_acc: 0.6949
#
# Balanced Accuracy - val: 0.763
# Epoch 276/300
#  - 1s - loss: 0.9498 - acc: 0.8525 - val_loss: 10.1305 - val_acc: 0.6633
#
# Balanced Accuracy - val: 0.739
# Epoch 277/300
#  - 0s - loss: 0.9611 - acc: 0.8584 - val_loss: 10.6835 - val_acc: 0.6849
#
# Balanced Accuracy - val: 0.755
# Epoch 278/300
#  - 0s - loss: 0.9714 - acc: 0.8553 - val_loss: 10.5405 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.740
# Epoch 279/300
#  - 1s - loss: 0.9849 - acc: 0.8536 - val_loss: 11.0919 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.732
# Epoch 280/300
#  - 1s - loss: 0.9677 - acc: 0.8565 - val_loss: 11.2351 - val_acc: 0.6569
#
# Balanced Accuracy - val: 0.730
# Epoch 281/300
#  - 0s - loss: 0.9916 - acc: 0.8532 - val_loss: 10.1083 - val_acc: 0.6849
#
# Balanced Accuracy - val: 0.746
# Epoch 282/300
#  - 0s - loss: 0.9314 - acc: 0.8611 - val_loss: 10.8576 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.732
# Epoch 283/300
#  - 1s - loss: 0.9532 - acc: 0.8602 - val_loss: 10.8767 - val_acc: 0.6705
#
# Balanced Accuracy - val: 0.741
# Epoch 284/300
#  - 1s - loss: 0.9416 - acc: 0.8609 - val_loss: 10.3508 - val_acc: 0.6884
#
# Balanced Accuracy - val: 0.759
# Epoch 285/300
#  - 1s - loss: 0.9484 - acc: 0.8584 - val_loss: 10.1631 - val_acc: 0.6626
#
# Balanced Accuracy - val: 0.736
# Epoch 286/300
#  - 1s - loss: 0.9501 - acc: 0.8564 - val_loss: 10.3401 - val_acc: 0.6619
#
# Balanced Accuracy - val: 0.738
# Epoch 287/300
#  - 1s - loss: 0.9455 - acc: 0.8615 - val_loss: 11.1548 - val_acc: 0.6762
#
# Balanced Accuracy - val: 0.746
# Epoch 288/300
#  - 1s - loss: 0.9497 - acc: 0.8611 - val_loss: 10.8804 - val_acc: 0.6576
#
# Balanced Accuracy - val: 0.737
# Epoch 289/300
#  - 1s - loss: 0.9317 - acc: 0.8605 - val_loss: 11.4749 - val_acc: 0.6655
#
# Balanced Accuracy - val: 0.739
# Epoch 290/300
#  - 0s - loss: 0.9241 - acc: 0.8608 - val_loss: 11.7257 - val_acc: 0.6339
#
# Balanced Accuracy - val: 0.717
# Epoch 291/300
#  - 1s - loss: 0.9591 - acc: 0.8590 - val_loss: 10.6317 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.746
# Epoch 292/300
#  - 1s - loss: 0.9515 - acc: 0.8567 - val_loss: 11.0629 - val_acc: 0.6482
#
# Balanced Accuracy - val: 0.730
# Epoch 293/300
#  - 1s - loss: 0.9531 - acc: 0.8630 - val_loss: 10.6530 - val_acc: 0.6683
#
# Balanced Accuracy - val: 0.749
# Epoch 294/300
#  - 1s - loss: 0.9460 - acc: 0.8597 - val_loss: 10.6748 - val_acc: 0.6734
#
# Balanced Accuracy - val: 0.745
# Epoch 295/300
#  - 0s - loss: 0.9530 - acc: 0.8586 - val_loss: 10.2740 - val_acc: 0.6683
#
# Balanced Accuracy - val: 0.742
# Epoch 296/300
#  - 0s - loss: 0.9627 - acc: 0.8590 - val_loss: 11.3065 - val_acc: 0.6317
#
# Balanced Accuracy - val: 0.721
# Epoch 297/300
#  - 0s - loss: 0.9329 - acc: 0.8582 - val_loss: 10.7083 - val_acc: 0.6719
#
# Balanced Accuracy - val: 0.748
# Epoch 298/300
#  - 1s - loss: 0.9620 - acc: 0.8559 - val_loss: 11.0700 - val_acc: 0.6375
#
# Balanced Accuracy - val: 0.723
# Epoch 299/300
#  - 0s - loss: 0.9596 - acc: 0.8550 - val_loss: 10.7188 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.725
# Epoch 300/300
#  - 0s - loss: 0.9716 - acc: 0.8541 - val_loss: 10.5809 - val_acc: 0.6748
#
# Balanced Accuracy - val: 0.745

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
print(history.history["acc"][-1])

# TRAIN SET
preds = model.predict(X_train)

# decode one-hot to single labels
preds = [ np.argmax(pred, axis = 0) for pred in preds ]
labels = [ np.argmax(label, axis = 0) for label in y_train_one_hot ]

# Compute confusion matrix
cnf_matrix = confusion_matrix(labels, preds)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                      title='Normalized confusion matrix - Train set')

# TEST SET
preds = model.predict(X_test)

# decode one-hot to single labels
preds = [ np.argmax(pred, axis = 0) for pred in preds ]
labels = [ np.argmax(label, axis = 0) for label in y_test_one_hot ]

# Compute confusion matrix
cnf_matrix = confusion_matrix(labels, preds)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                      title='Normalized confusion matrix - Test set')

plt.show()
# Out:
# 0.854071031607

# %%
model2 = Sequential()
#model.add(Reshape((X_train.shape[1], X_train.shape[2]), input_shape=(1, X_train.shape[1], X_train.shape[2])))
#model.add(Conv1D(32, 3, padding='same', input_shape=(X_train.shape[1], X_train.shape[2])))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
#print(model.output_shape)
#model.add(Flatten())
#model.add(GlobalAveragePooling1D())
model2.add(Dense(256, init='uniform', input_shape = (X_train.shape[1],)))
model2.add(BatchNormalization())
model2.add(Activation('relu'))
model2.add(Dropout(0.5))
model2.add(Dense(128, kernel_initializer="uniform"))
model2.add(BatchNormalization())
model2.add(Activation('relu'))
model2.add(Dropout(0.5))
model2.add(Dense(3, activation = 'softmax'))

adam = Adam(lr = 0.01)
y_train_one_hot = one_hot(y_train, 3)
y_test_one_hot = one_hot(y_test, 3)

model2.compile(loss=w_cat_crossentropy, optimizer=adam, metrics=['accuracy'])

history2 = model2.fit(X_train, y_train_one_hot, epochs=300, batch_size=512, validation_data=(X_test, y_test_one_hot), 
          verbose=2, shuffle=True, callbacks=CALLBACKS)
# Out:
# /Users/Nikos/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, input_shape=(60,), kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# Train on 16556 samples, validate on 1393 samples
# Epoch 1/300
#  - 2s - loss: 2.8959 - acc: 0.5432 - val_loss: 7.0749 - val_acc: 0.4365
#
# Balanced Accuracy - val: 0.432
# Epoch 2/300
#  - 1s - loss: 2.0479 - acc: 0.6712 - val_loss: 9.3971 - val_acc: 0.5075
#
# Balanced Accuracy - val: 0.627
# Epoch 3/300
#  - 1s - loss: 1.8006 - acc: 0.7173 - val_loss: 8.2163 - val_acc: 0.5355
#
# Balanced Accuracy - val: 0.617
# Epoch 4/300
#  - 1s - loss: 1.5869 - acc: 0.7498 - val_loss: 9.8958 - val_acc: 0.6052
#
# Balanced Accuracy - val: 0.647
# Epoch 5/300
#  - 1s - loss: 1.4404 - acc: 0.7719 - val_loss: 8.3775 - val_acc: 0.6001
#
# Balanced Accuracy - val: 0.618
# Epoch 6/300
#  - 1s - loss: 1.3939 - acc: 0.7817 - val_loss: 6.5470 - val_acc: 0.6906
#
# Balanced Accuracy - val: 0.721
# Epoch 7/300
#  - 1s - loss: 1.3108 - acc: 0.7919 - val_loss: 7.9268 - val_acc: 0.6346
#
# Balanced Accuracy - val: 0.656
# Epoch 8/300
#  - 1s - loss: 1.2198 - acc: 0.8076 - val_loss: 8.9160 - val_acc: 0.6260
#
# Balanced Accuracy - val: 0.646
# Epoch 9/300
#  - 1s - loss: 1.1732 - acc: 0.8141 - val_loss: 8.7061 - val_acc: 0.6791
#
# Balanced Accuracy - val: 0.678
# Epoch 10/300
#  - 1s - loss: 1.1390 - acc: 0.8161 - val_loss: 8.2916 - val_acc: 0.6597
#
# Balanced Accuracy - val: 0.684
# Epoch 11/300
#  - 1s - loss: 1.0847 - acc: 0.8272 - val_loss: 9.1190 - val_acc: 0.6525
#
# Balanced Accuracy - val: 0.685
# Epoch 12/300
#  - 1s - loss: 1.0846 - acc: 0.8279 - val_loss: 8.1206 - val_acc: 0.6648
#
# Balanced Accuracy - val: 0.618
# Epoch 13/300
#  - 1s - loss: 1.0818 - acc: 0.8300 - val_loss: 8.4072 - val_acc: 0.6741
#
# Balanced Accuracy - val: 0.682
# Epoch 14/300
#  - 1s - loss: 1.0054 - acc: 0.8430 - val_loss: 7.4319 - val_acc: 0.7150
#
# Balanced Accuracy - val: 0.679
# Epoch 15/300
#  - 1s - loss: 1.0319 - acc: 0.8381 - val_loss: 6.7009 - val_acc: 0.7373
#
# Balanced Accuracy - val: 0.717
# Epoch 16/300
#  - 1s - loss: 0.9713 - acc: 0.8454 - val_loss: 7.1055 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.684
# Epoch 17/300
#  - 1s - loss: 0.9553 - acc: 0.8454 - val_loss: 6.8596 - val_acc: 0.7566
#
# Balanced Accuracy - val: 0.732
# Epoch 18/300
#  - 1s - loss: 0.9479 - acc: 0.8508 - val_loss: 9.1302 - val_acc: 0.6339
#
# Balanced Accuracy - val: 0.752
# Epoch 19/300
#  - 1s - loss: 0.9402 - acc: 0.8531 - val_loss: 8.3464 - val_acc: 0.6662
#
# Balanced Accuracy - val: 0.676
# Epoch 20/300
#  - 1s - loss: 0.9483 - acc: 0.8501 - val_loss: 7.4965 - val_acc: 0.7330
#
# Balanced Accuracy - val: 0.692
# Epoch 21/300
#  - 1s - loss: 0.9149 - acc: 0.8558 - val_loss: 7.9954 - val_acc: 0.7042
#
# Balanced Accuracy - val: 0.693
# Epoch 22/300
#  - 1s - loss: 0.8801 - acc: 0.8628 - val_loss: 6.9645 - val_acc: 0.7150
#
# Balanced Accuracy - val: 0.732
# Epoch 23/300
#  - 1s - loss: 0.8838 - acc: 0.8630 - val_loss: 8.7771 - val_acc: 0.6676
#
# Balanced Accuracy - val: 0.669
# Epoch 24/300
#  - 1s - loss: 0.8990 - acc: 0.8607 - val_loss: 7.1992 - val_acc: 0.6956
#
# Balanced Accuracy - val: 0.744
# Epoch 25/300
#  - 1s - loss: 0.8528 - acc: 0.8652 - val_loss: 7.1079 - val_acc: 0.7523
#
# Balanced Accuracy - val: 0.756
# Epoch 26/300
#  - 1s - loss: 0.8588 - acc: 0.8657 - val_loss: 7.5062 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.741
# Epoch 27/300
#  - 1s - loss: 0.8496 - acc: 0.8677 - val_loss: 6.7605 - val_acc: 0.7609
#
# Balanced Accuracy - val: 0.788
# Epoch 28/300
#  - 1s - loss: 0.8506 - acc: 0.8665 - val_loss: 7.4246 - val_acc: 0.7157
#
# Balanced Accuracy - val: 0.730
# Epoch 29/300
#  - 1s - loss: 0.8173 - acc: 0.8700 - val_loss: 7.1100 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.689
# Epoch 30/300
#  - 1s - loss: 0.8616 - acc: 0.8615 - val_loss: 7.5017 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.709
# Epoch 31/300
#  - 1s - loss: 0.8009 - acc: 0.8704 - val_loss: 7.6332 - val_acc: 0.7387
#
# Balanced Accuracy - val: 0.719
# Epoch 32/300
#  - 1s - loss: 0.8083 - acc: 0.8702 - val_loss: 6.7669 - val_acc: 0.7272
#
# Balanced Accuracy - val: 0.733
# Epoch 33/300
#  - 1s - loss: 0.8345 - acc: 0.8730 - val_loss: 7.0710 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.696
# Epoch 34/300
#  - 1s - loss: 0.8072 - acc: 0.8727 - val_loss: 7.1558 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.717
# Epoch 35/300
#  - 1s - loss: 0.7930 - acc: 0.8742 - val_loss: 7.7257 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.743
# Epoch 36/300
#  - 1s - loss: 0.7788 - acc: 0.8779 - val_loss: 8.9861 - val_acc: 0.7050
#
# Balanced Accuracy - val: 0.744
# Epoch 37/300
#  - 1s - loss: 0.7802 - acc: 0.8748 - val_loss: 7.3547 - val_acc: 0.7710
#
# Balanced Accuracy - val: 0.768
# Epoch 38/300
#  - 1s - loss: 0.7439 - acc: 0.8828 - val_loss: 7.2325 - val_acc: 0.7552
#
# Balanced Accuracy - val: 0.732
# Epoch 39/300
#  - 1s - loss: 0.7636 - acc: 0.8817 - val_loss: 8.3380 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.752
# Epoch 40/300
#  - 1s - loss: 0.7853 - acc: 0.8721 - val_loss: 8.0785 - val_acc: 0.7322
#
# Balanced Accuracy - val: 0.746
# Epoch 41/300
#  - 1s - loss: 0.7530 - acc: 0.8816 - val_loss: 8.0247 - val_acc: 0.7229
#
# Balanced Accuracy - val: 0.761
# Epoch 42/300
#  - 1s - loss: 0.7530 - acc: 0.8814 - val_loss: 8.6933 - val_acc: 0.6935
#
# Balanced Accuracy - val: 0.742
# Epoch 43/300
#  - 1s - loss: 0.7706 - acc: 0.8823 - val_loss: 8.0130 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.733
# Epoch 44/300
#  - 1s - loss: 0.7377 - acc: 0.8826 - val_loss: 8.4764 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.710
# Epoch 45/300
#  - 1s - loss: 0.7569 - acc: 0.8816 - val_loss: 8.6649 - val_acc: 0.7057
#
# Balanced Accuracy - val: 0.772
# Epoch 46/300
#  - 1s - loss: 0.7148 - acc: 0.8884 - val_loss: 8.2199 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.710
# Epoch 47/300
#  - 1s - loss: 0.7407 - acc: 0.8873 - val_loss: 8.8743 - val_acc: 0.7107
#
# Balanced Accuracy - val: 0.703
# Epoch 48/300
#  - 1s - loss: 0.7580 - acc: 0.8841 - val_loss: 6.8342 - val_acc: 0.7430
#
# Balanced Accuracy - val: 0.752
# Epoch 49/300
#  - 1s - loss: 0.7548 - acc: 0.8825 - val_loss: 7.5490 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.720
# Epoch 50/300
#  - 1s - loss: 0.7298 - acc: 0.8834 - val_loss: 8.0707 - val_acc: 0.6963
#
# Balanced Accuracy - val: 0.716
# Epoch 51/300
#  - 1s - loss: 0.7198 - acc: 0.8891 - val_loss: 7.9017 - val_acc: 0.7480
#
# Balanced Accuracy - val: 0.728
# Epoch 52/300
#  - 1s - loss: 0.7217 - acc: 0.8848 - val_loss: 7.8734 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.694
# Epoch 53/300
#  - 1s - loss: 0.7287 - acc: 0.8870 - val_loss: 8.1102 - val_acc: 0.7215
#
# Balanced Accuracy - val: 0.710
# Epoch 54/300
#  - 1s - loss: 0.6963 - acc: 0.8918 - val_loss: 8.2874 - val_acc: 0.7286
#
# Balanced Accuracy - val: 0.691
# Epoch 55/300
#  - 1s - loss: 0.6999 - acc: 0.8898 - val_loss: 7.8748 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.713
# Epoch 56/300
#  - 1s - loss: 0.7110 - acc: 0.8893 - val_loss: 7.8875 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.720
# Epoch 57/300
#  - 1s - loss: 0.7166 - acc: 0.8885 - val_loss: 8.6753 - val_acc: 0.7272
#
# Balanced Accuracy - val: 0.742
# Epoch 58/300
#  - 1s - loss: 0.6687 - acc: 0.8968 - val_loss: 8.0094 - val_acc: 0.7688
#
# Balanced Accuracy - val: 0.744
# Epoch 59/300
#  - 1s - loss: 0.6816 - acc: 0.8916 - val_loss: 9.1093 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.742
# Epoch 60/300
#  - 1s - loss: 0.6808 - acc: 0.8956 - val_loss: 7.9030 - val_acc: 0.7574
#
# Balanced Accuracy - val: 0.709
# Epoch 61/300
#  - 1s - loss: 0.6743 - acc: 0.8924 - val_loss: 8.5276 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.756
# Epoch 62/300
#  - 1s - loss: 0.6817 - acc: 0.8939 - val_loss: 8.5260 - val_acc: 0.7416
#
# Balanced Accuracy - val: 0.726
# Epoch 63/300
#  - 1s - loss: 0.7001 - acc: 0.8910 - val_loss: 8.5663 - val_acc: 0.7308
#
# Balanced Accuracy - val: 0.720
# Epoch 64/300
#  - 1s - loss: 0.6997 - acc: 0.8899 - val_loss: 10.4823 - val_acc: 0.6705
#
# Balanced Accuracy - val: 0.703
# Epoch 65/300
#  - 1s - loss: 0.6800 - acc: 0.8927 - val_loss: 9.9210 - val_acc: 0.6985
#
# Balanced Accuracy - val: 0.721
# Epoch 66/300
#  - 1s - loss: 0.6883 - acc: 0.8950 - val_loss: 7.9897 - val_acc: 0.7380
#
# Balanced Accuracy - val: 0.722
# Epoch 67/300
#  - 1s - loss: 0.6776 - acc: 0.8959 - val_loss: 8.8330 - val_acc: 0.7315
#
# Balanced Accuracy - val: 0.719
# Epoch 68/300
#  - 1s - loss: 0.6470 - acc: 0.8973 - val_loss: 8.1966 - val_acc: 0.7121
#
# Balanced Accuracy - val: 0.730
# Epoch 69/300
#  - 1s - loss: 0.6477 - acc: 0.8975 - val_loss: 8.3626 - val_acc: 0.7128
#
# Balanced Accuracy - val: 0.730
# Epoch 70/300
#  - 1s - loss: 0.6804 - acc: 0.8948 - val_loss: 8.9086 - val_acc: 0.7322
#
# Balanced Accuracy - val: 0.743
# Epoch 71/300
#  - 1s - loss: 0.6689 - acc: 0.8939 - val_loss: 8.4308 - val_acc: 0.7315
#
# Balanced Accuracy - val: 0.743
# Epoch 72/300
#  - 1s - loss: 0.6572 - acc: 0.8950 - val_loss: 8.6763 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.742
# Epoch 73/300
#  - 1s - loss: 0.6460 - acc: 0.8979 - val_loss: 9.5910 - val_acc: 0.7035
#
# Balanced Accuracy - val: 0.699
# Epoch 74/300
#  - 1s - loss: 0.6330 - acc: 0.9016 - val_loss: 8.2398 - val_acc: 0.7480
#
# Balanced Accuracy - val: 0.730
# Epoch 75/300
#  - 1s - loss: 0.6452 - acc: 0.8970 - val_loss: 9.4867 - val_acc: 0.7186
#
# Balanced Accuracy - val: 0.709
# Epoch 76/300
#  - 1s - loss: 0.6445 - acc: 0.9035 - val_loss: 8.2407 - val_acc: 0.7688
#
# Balanced Accuracy - val: 0.742
# Epoch 77/300
#  - 1s - loss: 0.6560 - acc: 0.8953 - val_loss: 9.1008 - val_acc: 0.7423
#
# Balanced Accuracy - val: 0.725
# Epoch 78/300
#  - 1s - loss: 0.6563 - acc: 0.8971 - val_loss: 8.3856 - val_acc: 0.7638
#
# Balanced Accuracy - val: 0.738
# Epoch 79/300
#  - 1s - loss: 0.6618 - acc: 0.8965 - val_loss: 8.6155 - val_acc: 0.7653
#
# Balanced Accuracy - val: 0.743
# Epoch 80/300
#  - 1s - loss: 0.6203 - acc: 0.8991 - val_loss: 9.0166 - val_acc: 0.7609
#
# Balanced Accuracy - val: 0.740
# Epoch 81/300
#  - 1s - loss: 0.6388 - acc: 0.9006 - val_loss: 10.1154 - val_acc: 0.7236
#
# Balanced Accuracy - val: 0.738
# Epoch 82/300
#  - 1s - loss: 0.6631 - acc: 0.9012 - val_loss: 9.0864 - val_acc: 0.7315
#
# Balanced Accuracy - val: 0.744
# Epoch 83/300
#  - 1s - loss: 0.6210 - acc: 0.9029 - val_loss: 8.3584 - val_acc: 0.7531
#
# Balanced Accuracy - val: 0.734
# Epoch 84/300
#  - 1s - loss: 0.6622 - acc: 0.8946 - val_loss: 9.0880 - val_acc: 0.7459
#
# Balanced Accuracy - val: 0.678
# Epoch 85/300
#  - 1s - loss: 0.6350 - acc: 0.9028 - val_loss: 9.5458 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.707
# Epoch 86/300
#  - 1s - loss: 0.6556 - acc: 0.8984 - val_loss: 8.7419 - val_acc: 0.7401
#
# Balanced Accuracy - val: 0.699
# Epoch 87/300
#  - 1s - loss: 0.6247 - acc: 0.9031 - val_loss: 8.2070 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.745
# Epoch 88/300
#  - 1s - loss: 0.6387 - acc: 0.8994 - val_loss: 9.3957 - val_acc: 0.7050
#
# Balanced Accuracy - val: 0.730
# Epoch 89/300
#  - 1s - loss: 0.6426 - acc: 0.8987 - val_loss: 8.4483 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.732
# Epoch 90/300
#  - 1s - loss: 0.6371 - acc: 0.9005 - val_loss: 8.9891 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.732
# Epoch 91/300
#  - 1s - loss: 0.6152 - acc: 0.9006 - val_loss: 9.2474 - val_acc: 0.7229
#
# Balanced Accuracy - val: 0.738
# Epoch 92/300
#  - 1s - loss: 0.6692 - acc: 0.8965 - val_loss: 9.3613 - val_acc: 0.6920
#
# Balanced Accuracy - val: 0.716
# Epoch 93/300
#  - 1s - loss: 0.6300 - acc: 0.9016 - val_loss: 9.1709 - val_acc: 0.7057
#
# Balanced Accuracy - val: 0.752
# Epoch 94/300
#  - 1s - loss: 0.5978 - acc: 0.9075 - val_loss: 8.8840 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.736
# Epoch 95/300
#  - 1s - loss: 0.6302 - acc: 0.9004 - val_loss: 8.9675 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.769
# Epoch 96/300
#  - 1s - loss: 0.6391 - acc: 0.9040 - val_loss: 7.8811 - val_acc: 0.7624
#
# Balanced Accuracy - val: 0.764
# Epoch 97/300
#  - 1s - loss: 0.6417 - acc: 0.9011 - val_loss: 8.0918 - val_acc: 0.7473
#
# Balanced Accuracy - val: 0.755
# Epoch 98/300
#  - 1s - loss: 0.6109 - acc: 0.9058 - val_loss: 9.6965 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.735
# Epoch 99/300
#  - 1s - loss: 0.6357 - acc: 0.8985 - val_loss: 8.2325 - val_acc: 0.7301
#
# Balanced Accuracy - val: 0.743
# Epoch 100/300
#  - 1s - loss: 0.6369 - acc: 0.9009 - val_loss: 7.8434 - val_acc: 0.7459
#
# Balanced Accuracy - val: 0.757
# Epoch 101/300
#  - 1s - loss: 0.6292 - acc: 0.9000 - val_loss: 7.5219 - val_acc: 0.7653
#
# Balanced Accuracy - val: 0.767
# Epoch 102/300
#  - 1s - loss: 0.6149 - acc: 0.9038 - val_loss: 7.5848 - val_acc: 0.7789
#
# Balanced Accuracy - val: 0.777
# Epoch 103/300
#  - 1s - loss: 0.6179 - acc: 0.9043 - val_loss: 9.8121 - val_acc: 0.7172
#
# Balanced Accuracy - val: 0.762
# Epoch 104/300
#  - 1s - loss: 0.6050 - acc: 0.9093 - val_loss: 8.8143 - val_acc: 0.7574
#
# Balanced Accuracy - val: 0.763
# Epoch 105/300
#  - 1s - loss: 0.6141 - acc: 0.9037 - val_loss: 9.0500 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.738
# Epoch 106/300
#  - 1s - loss: 0.6002 - acc: 0.9073 - val_loss: 10.2429 - val_acc: 0.7085
#
# Balanced Accuracy - val: 0.727
# Epoch 107/300
#  - 1s - loss: 0.5752 - acc: 0.9090 - val_loss: 10.0397 - val_acc: 0.7128
#
# Balanced Accuracy - val: 0.705
# Epoch 108/300
#  - 1s - loss: 0.6056 - acc: 0.9060 - val_loss: 9.0815 - val_acc: 0.7595
#
# Balanced Accuracy - val: 0.737
# Epoch 109/300
#  - 1s - loss: 0.5830 - acc: 0.9096 - val_loss: 9.6473 - val_acc: 0.7301
#
# Balanced Accuracy - val: 0.716
# Epoch 110/300
#  - 1s - loss: 0.6417 - acc: 0.9034 - val_loss: 9.2173 - val_acc: 0.7430
#
# Balanced Accuracy - val: 0.726
# Epoch 111/300
#  - 1s - loss: 0.5904 - acc: 0.9072 - val_loss: 9.8436 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.707
# Epoch 112/300
#  - 1s - loss: 0.5580 - acc: 0.9124 - val_loss: 9.9849 - val_acc: 0.7078
#
# Balanced Accuracy - val: 0.678
# Epoch 113/300
#  - 1s - loss: 0.5870 - acc: 0.9107 - val_loss: 9.7349 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.709
# Epoch 114/300
#  - 1s - loss: 0.6186 - acc: 0.9003 - val_loss: 8.8085 - val_acc: 0.7100
#
# Balanced Accuracy - val: 0.701
# Epoch 115/300
#  - 1s - loss: 0.6031 - acc: 0.9079 - val_loss: 8.5378 - val_acc: 0.7617
#
# Balanced Accuracy - val: 0.766
# Epoch 116/300
#  - 1s - loss: 0.5942 - acc: 0.9070 - val_loss: 9.2484 - val_acc: 0.7200
#
# Balanced Accuracy - val: 0.734
# Epoch 117/300
#  - 1s - loss: 0.6156 - acc: 0.9087 - val_loss: 8.1845 - val_acc: 0.7358
#
# Balanced Accuracy - val: 0.722
# Epoch 118/300
#  - 1s - loss: 0.5880 - acc: 0.9070 - val_loss: 8.2299 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.712
# Epoch 119/300
#  - 1s - loss: 0.5782 - acc: 0.9102 - val_loss: 8.0491 - val_acc: 0.7631
#
# Balanced Accuracy - val: 0.714
# Epoch 120/300
#  - 1s - loss: 0.5907 - acc: 0.9083 - val_loss: 9.6904 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.739
# Epoch 121/300
#  - 1s - loss: 0.5971 - acc: 0.9064 - val_loss: 8.6693 - val_acc: 0.7617
#
# Balanced Accuracy - val: 0.716
# Epoch 122/300
#  - 1s - loss: 0.5830 - acc: 0.9098 - val_loss: 8.3736 - val_acc: 0.7574
#
# Balanced Accuracy - val: 0.785
# Epoch 123/300
#  - 1s - loss: 0.5699 - acc: 0.9096 - val_loss: 9.3761 - val_acc: 0.7121
#
# Balanced Accuracy - val: 0.732
# Epoch 124/300
#  - 1s - loss: 0.5711 - acc: 0.9112 - val_loss: 8.6319 - val_acc: 0.7337
#
# Balanced Accuracy - val: 0.742
# Epoch 125/300
#  - 1s - loss: 0.5666 - acc: 0.9102 - val_loss: 10.3955 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.706
# Epoch 126/300
#  - 1s - loss: 0.6027 - acc: 0.9097 - val_loss: 8.1741 - val_acc: 0.7645
#
# Balanced Accuracy - val: 0.742
# Epoch 127/300
#  - 1s - loss: 0.5712 - acc: 0.9111 - val_loss: 8.6689 - val_acc: 0.7559
#
# Balanced Accuracy - val: 0.736
# Epoch 128/300
#  - 1s - loss: 0.5698 - acc: 0.9114 - val_loss: 9.1410 - val_acc: 0.7330
#
# Balanced Accuracy - val: 0.766
# Epoch 129/300
#  - 1s - loss: 0.5866 - acc: 0.9072 - val_loss: 8.5455 - val_acc: 0.7696
#
# Balanced Accuracy - val: 0.769
# Epoch 130/300
#  - 1s - loss: 0.5774 - acc: 0.9082 - val_loss: 10.2704 - val_acc: 0.7042
#
# Balanced Accuracy - val: 0.724
# Epoch 131/300
#  - 1s - loss: 0.5714 - acc: 0.9158 - val_loss: 9.5727 - val_acc: 0.7502
#
# Balanced Accuracy - val: 0.730
# Epoch 132/300
#  - 1s - loss: 0.5745 - acc: 0.9107 - val_loss: 10.0861 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.733
# Epoch 133/300
#  - 1s - loss: 0.5667 - acc: 0.9116 - val_loss: 9.2846 - val_acc: 0.7373
#
# Balanced Accuracy - val: 0.749
# Epoch 134/300
#  - 1s - loss: 0.5702 - acc: 0.9140 - val_loss: 9.4179 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.739
# Epoch 135/300
#  - 1s - loss: 0.5671 - acc: 0.9122 - val_loss: 10.4103 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.681
# Epoch 136/300
#  - 1s - loss: 0.5576 - acc: 0.9112 - val_loss: 10.0519 - val_acc: 0.6913
#
# Balanced Accuracy - val: 0.713
# Epoch 137/300
#  - 1s - loss: 0.6184 - acc: 0.9023 - val_loss: 11.2868 - val_acc: 0.7050
#
# Balanced Accuracy - val: 0.723
# Epoch 138/300
#  - 1s - loss: 0.5865 - acc: 0.9066 - val_loss: 8.6920 - val_acc: 0.7444
#
# Balanced Accuracy - val: 0.749
# Epoch 139/300
#  - 1s - loss: 0.5735 - acc: 0.9084 - val_loss: 9.2553 - val_acc: 0.7330
#
# Balanced Accuracy - val: 0.744
# Epoch 140/300
#  - 1s - loss: 0.5557 - acc: 0.9113 - val_loss: 9.6284 - val_acc: 0.7265
#
# Balanced Accuracy - val: 0.740
# Epoch 141/300
#  - 1s - loss: 0.5515 - acc: 0.9166 - val_loss: 10.7571 - val_acc: 0.6999
#
# Balanced Accuracy - val: 0.673
# Epoch 142/300
#  - 1s - loss: 0.5561 - acc: 0.9147 - val_loss: 9.0385 - val_acc: 0.7437
#
# Balanced Accuracy - val: 0.777
# Epoch 143/300
#  - 1s - loss: 0.5580 - acc: 0.9109 - val_loss: 10.1259 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.779
# Epoch 144/300
#  - 1s - loss: 0.5692 - acc: 0.9112 - val_loss: 9.9768 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.793
# Epoch 145/300
#  - 1s - loss: 0.5618 - acc: 0.9134 - val_loss: 9.9664 - val_acc: 0.6992
#
# Balanced Accuracy - val: 0.745
# Epoch 146/300
#  - 1s - loss: 0.5523 - acc: 0.9127 - val_loss: 10.0986 - val_acc: 0.7150
#
# Balanced Accuracy - val: 0.761
# Epoch 147/300
#  - 1s - loss: 0.5634 - acc: 0.9112 - val_loss: 9.7857 - val_acc: 0.7466
#
# Balanced Accuracy - val: 0.754
# Epoch 148/300
#  - 1s - loss: 0.5280 - acc: 0.9169 - val_loss: 10.1484 - val_acc: 0.7444
#
# Balanced Accuracy - val: 0.756
# Epoch 149/300
#  - 1s - loss: 0.5723 - acc: 0.9125 - val_loss: 9.5479 - val_acc: 0.7337
#
# Balanced Accuracy - val: 0.720
# Epoch 150/300
#  - 1s - loss: 0.5641 - acc: 0.9116 - val_loss: 9.5195 - val_acc: 0.7416
#
# Balanced Accuracy - val: 0.725
# Epoch 151/300
#  - 1s - loss: 0.5413 - acc: 0.9187 - val_loss: 10.4200 - val_acc: 0.7416
#
# Balanced Accuracy - val: 0.753
# Epoch 152/300
#  - 1s - loss: 0.5270 - acc: 0.9187 - val_loss: 10.2122 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.702
# Epoch 153/300
#  - 1s - loss: 0.5599 - acc: 0.9136 - val_loss: 9.8384 - val_acc: 0.7416
#
# Balanced Accuracy - val: 0.722
# Epoch 154/300
#  - 1s - loss: 0.5752 - acc: 0.9122 - val_loss: 9.3862 - val_acc: 0.7674
#
# Balanced Accuracy - val: 0.746
# Epoch 155/300
#  - 1s - loss: 0.5318 - acc: 0.9185 - val_loss: 9.9083 - val_acc: 0.7473
#
# Balanced Accuracy - val: 0.754
# Epoch 156/300
#  - 1s - loss: 0.5839 - acc: 0.9106 - val_loss: 9.5584 - val_acc: 0.7308
#
# Balanced Accuracy - val: 0.719
# Epoch 157/300
#  - 1s - loss: 0.5978 - acc: 0.9087 - val_loss: 8.3996 - val_acc: 0.7581
#
# Balanced Accuracy - val: 0.735
# Epoch 158/300
#  - 1s - loss: 0.5413 - acc: 0.9174 - val_loss: 8.8199 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.719
# Epoch 159/300
#  - 1s - loss: 0.5171 - acc: 0.9169 - val_loss: 9.6862 - val_acc: 0.7574
#
# Balanced Accuracy - val: 0.736
# Epoch 160/300
#  - 1s - loss: 0.5280 - acc: 0.9166 - val_loss: 9.6049 - val_acc: 0.7322
#
# Balanced Accuracy - val: 0.693
# Epoch 161/300
#  - 1s - loss: 0.5337 - acc: 0.9150 - val_loss: 10.1791 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.688
# Epoch 162/300
#  - 1s - loss: 0.5195 - acc: 0.9224 - val_loss: 9.5817 - val_acc: 0.7265
#
# Balanced Accuracy - val: 0.689
# Epoch 163/300
#  - 1s - loss: 0.5389 - acc: 0.9175 - val_loss: 9.6941 - val_acc: 0.7487
#
# Balanced Accuracy - val: 0.730
# Epoch 164/300
#  - 1s - loss: 0.5421 - acc: 0.9160 - val_loss: 10.1180 - val_acc: 0.7480
#
# Balanced Accuracy - val: 0.704
# Epoch 165/300
#  - 1s - loss: 0.5400 - acc: 0.9160 - val_loss: 9.1402 - val_acc: 0.7416
#
# Balanced Accuracy - val: 0.723
# Epoch 166/300
#  - 1s - loss: 0.5214 - acc: 0.9214 - val_loss: 9.4060 - val_acc: 0.7408
#
# Balanced Accuracy - val: 0.725
# Epoch 167/300
#  - 1s - loss: 0.5544 - acc: 0.9156 - val_loss: 9.6837 - val_acc: 0.7365
#
# Balanced Accuracy - val: 0.720
# Epoch 168/300
#  - 1s - loss: 0.5382 - acc: 0.9154 - val_loss: 10.6503 - val_acc: 0.7093
#
# Balanced Accuracy - val: 0.677
# Epoch 169/300
#  - 1s - loss: 0.5332 - acc: 0.9178 - val_loss: 8.6462 - val_acc: 0.7559
#
# Balanced Accuracy - val: 0.708
# Epoch 170/300
#  - 1s - loss: 0.5493 - acc: 0.9171 - val_loss: 9.9887 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.697
# Epoch 171/300
#  - 1s - loss: 0.5453 - acc: 0.9199 - val_loss: 8.5837 - val_acc: 0.7466
#
# Balanced Accuracy - val: 0.729
# Epoch 172/300
#  - 1s - loss: 0.5242 - acc: 0.9170 - val_loss: 10.4960 - val_acc: 0.7143
#
# Balanced Accuracy - val: 0.679
# Epoch 173/300
#  - 1s - loss: 0.5556 - acc: 0.9121 - val_loss: 10.4916 - val_acc: 0.7093
#
# Balanced Accuracy - val: 0.701
# Epoch 174/300
#  - 1s - loss: 0.5437 - acc: 0.9151 - val_loss: 10.6218 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.714
# Epoch 175/300
#  - 1s - loss: 0.5261 - acc: 0.9192 - val_loss: 9.9017 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.749
# Epoch 176/300
#  - 1s - loss: 0.5240 - acc: 0.9188 - val_loss: 9.5544 - val_acc: 0.7552
#
# Balanced Accuracy - val: 0.710
# Epoch 177/300
#  - 1s - loss: 0.5168 - acc: 0.9175 - val_loss: 10.7793 - val_acc: 0.7473
#
# Balanced Accuracy - val: 0.705
# Epoch 178/300
#  - 1s - loss: 0.5333 - acc: 0.9160 - val_loss: 9.6254 - val_acc: 0.7387
#
# Balanced Accuracy - val: 0.697
# Epoch 179/300
#  - 1s - loss: 0.5449 - acc: 0.9179 - val_loss: 11.0037 - val_acc: 0.7093
#
# Balanced Accuracy - val: 0.754
# Epoch 180/300
#  - 1s - loss: 0.5315 - acc: 0.9159 - val_loss: 10.5639 - val_acc: 0.7322
#
# Balanced Accuracy - val: 0.720
# Epoch 181/300
#  - 1s - loss: 0.5357 - acc: 0.9166 - val_loss: 10.4902 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.742
# Epoch 182/300
#  - 1s - loss: 0.5286 - acc: 0.9166 - val_loss: 10.6165 - val_acc: 0.7301
#
# Balanced Accuracy - val: 0.719
# Epoch 183/300
#  - 1s - loss: 0.5514 - acc: 0.9170 - val_loss: 9.7434 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.748
# Epoch 184/300
#  - 1s - loss: 0.5092 - acc: 0.9214 - val_loss: 10.4511 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.722
# Epoch 185/300
#  - 1s - loss: 0.5470 - acc: 0.9179 - val_loss: 10.1663 - val_acc: 0.7308
#
# Balanced Accuracy - val: 0.692
# Epoch 186/300
#  - 1s - loss: 0.5396 - acc: 0.9205 - val_loss: 9.5186 - val_acc: 0.7617
#
# Balanced Accuracy - val: 0.715
# Epoch 187/300
#  - 1s - loss: 0.5387 - acc: 0.9186 - val_loss: 9.3486 - val_acc: 0.7459
#
# Balanced Accuracy - val: 0.703
# Epoch 188/300
#  - 1s - loss: 0.5125 - acc: 0.9182 - val_loss: 10.4803 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.694
# Epoch 189/300
#  - 1s - loss: 0.5242 - acc: 0.9230 - val_loss: 10.0790 - val_acc: 0.7315
#
# Balanced Accuracy - val: 0.739
# Epoch 190/300
#  - 1s - loss: 0.5171 - acc: 0.9206 - val_loss: 10.2556 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.722
# Epoch 191/300
#  - 1s - loss: 0.5116 - acc: 0.9212 - val_loss: 9.8178 - val_acc: 0.7487
#
# Balanced Accuracy - val: 0.703
# Epoch 192/300
#  - 1s - loss: 0.5445 - acc: 0.9167 - val_loss: 9.6149 - val_acc: 0.7531
#
# Balanced Accuracy - val: 0.709
# Epoch 193/300
#  - 1s - loss: 0.5410 - acc: 0.9189 - val_loss: 9.9747 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.706
# Epoch 194/300
#  - 1s - loss: 0.5163 - acc: 0.9224 - val_loss: 10.7701 - val_acc: 0.7222
#
# Balanced Accuracy - val: 0.713
# Epoch 195/300
#  - 1s - loss: 0.5049 - acc: 0.9198 - val_loss: 10.3412 - val_acc: 0.7236
#
# Balanced Accuracy - val: 0.686
# Epoch 196/300
#  - 1s - loss: 0.5516 - acc: 0.9149 - val_loss: 10.2859 - val_acc: 0.7078
#
# Balanced Accuracy - val: 0.700
# Epoch 197/300
#  - 1s - loss: 0.5394 - acc: 0.9173 - val_loss: 9.4004 - val_acc: 0.7523
#
# Balanced Accuracy - val: 0.706
# Epoch 198/300
#  - 1s - loss: 0.5424 - acc: 0.9180 - val_loss: 10.3631 - val_acc: 0.7121
#
# Balanced Accuracy - val: 0.679
# Epoch 199/300
#  - 1s - loss: 0.5138 - acc: 0.9175 - val_loss: 10.3599 - val_acc: 0.7143
#
# Balanced Accuracy - val: 0.681
# Epoch 200/300
#  - 1s - loss: 0.4890 - acc: 0.9217 - val_loss: 10.7117 - val_acc: 0.7495
#
# Balanced Accuracy - val: 0.704
# Epoch 201/300
#  - 1s - loss: 0.4982 - acc: 0.9217 - val_loss: 10.1354 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.686
# Epoch 202/300
#  - 1s - loss: 0.5132 - acc: 0.9204 - val_loss: 11.1799 - val_acc: 0.7028
#
# Balanced Accuracy - val: 0.697
# Epoch 203/300
#  - 1s - loss: 0.5286 - acc: 0.9191 - val_loss: 10.1593 - val_acc: 0.7315
#
# Balanced Accuracy - val: 0.716
# Epoch 204/300
#  - 1s - loss: 0.4887 - acc: 0.9237 - val_loss: 11.2879 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.707
# Epoch 205/300
#  - 1s - loss: 0.4960 - acc: 0.9256 - val_loss: 9.6456 - val_acc: 0.7531
#
# Balanced Accuracy - val: 0.733
# Epoch 206/300
#  - 1s - loss: 0.5233 - acc: 0.9206 - val_loss: 8.7047 - val_acc: 0.7545
#
# Balanced Accuracy - val: 0.708
# Epoch 207/300
#  - 1s - loss: 0.5107 - acc: 0.9210 - val_loss: 9.2075 - val_acc: 0.7401
#
# Balanced Accuracy - val: 0.725
# Epoch 208/300
#  - 1s - loss: 0.5137 - acc: 0.9214 - val_loss: 9.7900 - val_acc: 0.7337
#
# Balanced Accuracy - val: 0.716
# Epoch 209/300
#  - 1s - loss: 0.5059 - acc: 0.9205 - val_loss: 9.6266 - val_acc: 0.6971
#
# Balanced Accuracy - val: 0.748
# Epoch 210/300
#  - 1s - loss: 0.5421 - acc: 0.9139 - val_loss: 11.2168 - val_acc: 0.7387
#
# Balanced Accuracy - val: 0.727
# Epoch 211/300
#  - 1s - loss: 0.5221 - acc: 0.9194 - val_loss: 9.9382 - val_acc: 0.7638
#
# Balanced Accuracy - val: 0.739
# Epoch 212/300
#  - 1s - loss: 0.5073 - acc: 0.9237 - val_loss: 9.9791 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.714
# Epoch 213/300
#  - 1s - loss: 0.5081 - acc: 0.9210 - val_loss: 10.2390 - val_acc: 0.7207
#
# Balanced Accuracy - val: 0.710
# Epoch 214/300
#  - 1s - loss: 0.5318 - acc: 0.9192 - val_loss: 11.7320 - val_acc: 0.6992
#
# Balanced Accuracy - val: 0.697
# Epoch 215/300
#  - 1s - loss: 0.5210 - acc: 0.9221 - val_loss: 10.8706 - val_acc: 0.7200
#
# Balanced Accuracy - val: 0.713
# Epoch 216/300
#  - 1s - loss: 0.5202 - acc: 0.9203 - val_loss: 10.9763 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.712
# Epoch 217/300
#  - 1s - loss: 0.4953 - acc: 0.9255 - val_loss: 10.4960 - val_acc: 0.7050
#
# Balanced Accuracy - val: 0.700
# Epoch 218/300
#  - 1s - loss: 0.5009 - acc: 0.9243 - val_loss: 10.1584 - val_acc: 0.7495
#
# Balanced Accuracy - val: 0.706
# Epoch 219/300
#  - 1s - loss: 0.5051 - acc: 0.9210 - val_loss: 10.0143 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.697
# Epoch 220/300
#  - 1s - loss: 0.4852 - acc: 0.9258 - val_loss: 10.8373 - val_acc: 0.7021
#
# Balanced Accuracy - val: 0.723
# Epoch 221/300
#  - 1s - loss: 0.5142 - acc: 0.9221 - val_loss: 10.6972 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.744
# Epoch 222/300
#  - 1s - loss: 0.5421 - acc: 0.9148 - val_loss: 10.0130 - val_acc: 0.6949
#
# Balanced Accuracy - val: 0.741
# Epoch 223/300
#  - 1s - loss: 0.5260 - acc: 0.9214 - val_loss: 9.8064 - val_acc: 0.7495
#
# Balanced Accuracy - val: 0.730
# Epoch 224/300
#  - 1s - loss: 0.5342 - acc: 0.9188 - val_loss: 10.1401 - val_acc: 0.7301
#
# Balanced Accuracy - val: 0.743
# Epoch 225/300
#  - 1s - loss: 0.5116 - acc: 0.9221 - val_loss: 9.5369 - val_acc: 0.7093
#
# Balanced Accuracy - val: 0.731
# Epoch 226/300
#  - 1s - loss: 0.4918 - acc: 0.9252 - val_loss: 9.4139 - val_acc: 0.7380
#
# Balanced Accuracy - val: 0.721
# Epoch 227/300
#  - 1s - loss: 0.5044 - acc: 0.9171 - val_loss: 11.1723 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.757
# Epoch 228/300
#  - 1s - loss: 0.5135 - acc: 0.9225 - val_loss: 9.5393 - val_acc: 0.7473
#
# Balanced Accuracy - val: 0.778
# Epoch 229/300
#  - 1s - loss: 0.5005 - acc: 0.9250 - val_loss: 10.8841 - val_acc: 0.7179
#
# Balanced Accuracy - val: 0.737
# Epoch 230/300
#  - 1s - loss: 0.5109 - acc: 0.9200 - val_loss: 10.6666 - val_acc: 0.7114
#
# Balanced Accuracy - val: 0.729
# Epoch 231/300
#  - 1s - loss: 0.4805 - acc: 0.9272 - val_loss: 10.4977 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.758
# Epoch 232/300
#  - 1s - loss: 0.5057 - acc: 0.9247 - val_loss: 11.1338 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.760
# Epoch 233/300
#  - 1s - loss: 0.5045 - acc: 0.9243 - val_loss: 10.4965 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.726
# Epoch 234/300
#  - 1s - loss: 0.4997 - acc: 0.9222 - val_loss: 11.2879 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.765
# Epoch 235/300
#  - 1s - loss: 0.4938 - acc: 0.9230 - val_loss: 11.4125 - val_acc: 0.7150
#
# Balanced Accuracy - val: 0.759
# Epoch 236/300
#  - 1s - loss: 0.5102 - acc: 0.9211 - val_loss: 10.9770 - val_acc: 0.7085
#
# Balanced Accuracy - val: 0.707
# Epoch 237/300
#  - 1s - loss: 0.5038 - acc: 0.9214 - val_loss: 10.0311 - val_acc: 0.7545
#
# Balanced Accuracy - val: 0.736
# Epoch 238/300
#  - 1s - loss: 0.5425 - acc: 0.9189 - val_loss: 10.1569 - val_acc: 0.6971
#
# Balanced Accuracy - val: 0.721
# Epoch 239/300
#  - 1s - loss: 0.5143 - acc: 0.9197 - val_loss: 10.1618 - val_acc: 0.7272
#
# Balanced Accuracy - val: 0.742
# Epoch 240/300
#  - 1s - loss: 0.5067 - acc: 0.9227 - val_loss: 10.0768 - val_acc: 0.7186
#
# Balanced Accuracy - val: 0.711
# Epoch 241/300
#  - 1s - loss: 0.4906 - acc: 0.9262 - val_loss: 12.2881 - val_acc: 0.6999
#
# Balanced Accuracy - val: 0.700
# Epoch 242/300
#  - 1s - loss: 0.4736 - acc: 0.9281 - val_loss: 11.5958 - val_acc: 0.7143
#
# Balanced Accuracy - val: 0.710
# Epoch 243/300
#  - 1s - loss: 0.4762 - acc: 0.9265 - val_loss: 10.4977 - val_acc: 0.7330
#
# Balanced Accuracy - val: 0.724
# Epoch 244/300
#  - 1s - loss: 0.5056 - acc: 0.9258 - val_loss: 9.8488 - val_acc: 0.7480
#
# Balanced Accuracy - val: 0.757
# Epoch 245/300
#  - 1s - loss: 0.4835 - acc: 0.9262 - val_loss: 10.4662 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.697
# Epoch 246/300
#  - 1s - loss: 0.4857 - acc: 0.9240 - val_loss: 9.8164 - val_acc: 0.7401
#
# Balanced Accuracy - val: 0.728
# Epoch 247/300
#  - 1s - loss: 0.4787 - acc: 0.9290 - val_loss: 10.6079 - val_acc: 0.6963
#
# Balanced Accuracy - val: 0.697
# Epoch 248/300
#  - 1s - loss: 0.4759 - acc: 0.9261 - val_loss: 10.0100 - val_acc: 0.7236
#
# Balanced Accuracy - val: 0.738
# Epoch 249/300
#  - 1s - loss: 0.4621 - acc: 0.9290 - val_loss: 11.5638 - val_acc: 0.7157
#
# Balanced Accuracy - val: 0.737
# Epoch 250/300
#  - 1s - loss: 0.5154 - acc: 0.9230 - val_loss: 10.2753 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.740
# Epoch 251/300
#  - 1s - loss: 0.4871 - acc: 0.9279 - val_loss: 9.6836 - val_acc: 0.7143
#
# Balanced Accuracy - val: 0.731
# Epoch 252/300
#  - 1s - loss: 0.5484 - acc: 0.9171 - val_loss: 11.5402 - val_acc: 0.6712
#
# Balanced Accuracy - val: 0.726
# Epoch 253/300
#  - 1s - loss: 0.4904 - acc: 0.9270 - val_loss: 9.8690 - val_acc: 0.7265
#
# Balanced Accuracy - val: 0.717
# Epoch 254/300
#  - 1s - loss: 0.5018 - acc: 0.9234 - val_loss: 10.9246 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.741
# Epoch 255/300
#  - 1s - loss: 0.4928 - acc: 0.9258 - val_loss: 11.1798 - val_acc: 0.7552
#
# Balanced Accuracy - val: 0.736
# Epoch 256/300
#  - 1s - loss: 0.5072 - acc: 0.9226 - val_loss: 11.7374 - val_acc: 0.7387
#
# Balanced Accuracy - val: 0.725
# Epoch 257/300
#  - 1s - loss: 0.4962 - acc: 0.9254 - val_loss: 11.3761 - val_acc: 0.7229
#
# Balanced Accuracy - val: 0.736
# Epoch 258/300
#  - 1s - loss: 0.4965 - acc: 0.9248 - val_loss: 11.4161 - val_acc: 0.7430
#
# Balanced Accuracy - val: 0.701
# Epoch 259/300
#  - 1s - loss: 0.4823 - acc: 0.9264 - val_loss: 11.2832 - val_acc: 0.7100
#
# Balanced Accuracy - val: 0.756
# Epoch 260/300
#  - 1s - loss: 0.4783 - acc: 0.9259 - val_loss: 10.9030 - val_acc: 0.7193
#
# Balanced Accuracy - val: 0.740
# Epoch 261/300
#  - 1s - loss: 0.4936 - acc: 0.9261 - val_loss: 11.3784 - val_acc: 0.7121
#
# Balanced Accuracy - val: 0.732
# Epoch 262/300
#  - 1s - loss: 0.5115 - acc: 0.9194 - val_loss: 10.8704 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.773
# Epoch 263/300
#  - 1s - loss: 0.4991 - acc: 0.9269 - val_loss: 9.9879 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.744
# Epoch 264/300
#  - 1s - loss: 0.4936 - acc: 0.9264 - val_loss: 9.8517 - val_acc: 0.7459
#
# Balanced Accuracy - val: 0.754
# Epoch 265/300
#  - 1s - loss: 0.4638 - acc: 0.9263 - val_loss: 11.6025 - val_acc: 0.7251
#
# Balanced Accuracy - val: 0.745
# Epoch 266/300
#  - 1s - loss: 0.4873 - acc: 0.9308 - val_loss: 11.1552 - val_acc: 0.7459
#
# Balanced Accuracy - val: 0.781
# Epoch 267/300
#  - 1s - loss: 0.4902 - acc: 0.9255 - val_loss: 10.4612 - val_acc: 0.7480
#
# Balanced Accuracy - val: 0.758
# Epoch 268/300
#  - 1s - loss: 0.4758 - acc: 0.9285 - val_loss: 11.2846 - val_acc: 0.7236
#
# Balanced Accuracy - val: 0.738
# Epoch 269/300
#  - 1s - loss: 0.4778 - acc: 0.9290 - val_loss: 11.8947 - val_acc: 0.7078
#
# Balanced Accuracy - val: 0.730
# Epoch 270/300
#  - 1s - loss: 0.4732 - acc: 0.9292 - val_loss: 11.1431 - val_acc: 0.7344
#
# Balanced Accuracy - val: 0.748
# Epoch 271/300
#  - 1s - loss: 0.4825 - acc: 0.9247 - val_loss: 9.9471 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.734
# Epoch 272/300
#  - 1s - loss: 0.4673 - acc: 0.9292 - val_loss: 11.2085 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.709
# Epoch 273/300
#  - 1s - loss: 0.4754 - acc: 0.9263 - val_loss: 12.7621 - val_acc: 0.7121
#
# Balanced Accuracy - val: 0.709
# Epoch 274/300
#  - 1s - loss: 0.4855 - acc: 0.9253 - val_loss: 11.2786 - val_acc: 0.7373
#
# Balanced Accuracy - val: 0.775
# Epoch 275/300
#  - 1s - loss: 0.5021 - acc: 0.9239 - val_loss: 10.1151 - val_acc: 0.7495
#
# Balanced Accuracy - val: 0.707
# Epoch 276/300
#  - 1s - loss: 0.4764 - acc: 0.9264 - val_loss: 11.7670 - val_acc: 0.6805
#
# Balanced Accuracy - val: 0.736
# Epoch 277/300
#  - 1s - loss: 0.4781 - acc: 0.9266 - val_loss: 11.6115 - val_acc: 0.7021
#
# Balanced Accuracy - val: 0.724
# Epoch 278/300
#  - 1s - loss: 0.5148 - acc: 0.9230 - val_loss: 10.6115 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.738
# Epoch 279/300
#  - 1s - loss: 0.4839 - acc: 0.9251 - val_loss: 10.1243 - val_acc: 0.7588
#
# Balanced Accuracy - val: 0.737
# Epoch 280/300
#  - 1s - loss: 0.4497 - acc: 0.9316 - val_loss: 11.7156 - val_acc: 0.6978
#
# Balanced Accuracy - val: 0.695
# Epoch 281/300
#  - 1s - loss: 0.4640 - acc: 0.9269 - val_loss: 11.0778 - val_acc: 0.7351
#
# Balanced Accuracy - val: 0.746
# Epoch 282/300
#  - 1s - loss: 0.4687 - acc: 0.9258 - val_loss: 11.5692 - val_acc: 0.7243
#
# Balanced Accuracy - val: 0.712
# Epoch 283/300
#  - 1s - loss: 0.4680 - acc: 0.9287 - val_loss: 10.4658 - val_acc: 0.7286
#
# Balanced Accuracy - val: 0.742
# Epoch 284/300
#  - 1s - loss: 0.4947 - acc: 0.9235 - val_loss: 10.7025 - val_acc: 0.7229
#
# Balanced Accuracy - val: 0.765
# Epoch 285/300
#  - 1s - loss: 0.5023 - acc: 0.9232 - val_loss: 11.2442 - val_acc: 0.7107
#
# Balanced Accuracy - val: 0.730
# Epoch 286/300
#  - 1s - loss: 0.4975 - acc: 0.9253 - val_loss: 10.3570 - val_acc: 0.7408
#
# Balanced Accuracy - val: 0.727
# Epoch 287/300
#  - 1s - loss: 0.4685 - acc: 0.9246 - val_loss: 11.0983 - val_acc: 0.7186
#
# Balanced Accuracy - val: 0.707
# Epoch 288/300
#  - 1s - loss: 0.4533 - acc: 0.9314 - val_loss: 11.0595 - val_acc: 0.7373
#
# Balanced Accuracy - val: 0.749
# Epoch 289/300
#  - 1s - loss: 0.4559 - acc: 0.9281 - val_loss: 11.7193 - val_acc: 0.7164
#
# Balanced Accuracy - val: 0.711
# Epoch 290/300
#  - 1s - loss: 0.4811 - acc: 0.9269 - val_loss: 12.5294 - val_acc: 0.6920
#
# Balanced Accuracy - val: 0.744
# Epoch 291/300
#  - 1s - loss: 0.4711 - acc: 0.9279 - val_loss: 11.5618 - val_acc: 0.7064
#
# Balanced Accuracy - val: 0.729
# Epoch 292/300
#  - 1s - loss: 0.5013 - acc: 0.9253 - val_loss: 11.0504 - val_acc: 0.7157
#
# Balanced Accuracy - val: 0.709
# Epoch 293/300
#  - 1s - loss: 0.4976 - acc: 0.9269 - val_loss: 10.4214 - val_acc: 0.7365
#
# Balanced Accuracy - val: 0.724
# Epoch 294/300
#  - 1s - loss: 0.4593 - acc: 0.9299 - val_loss: 11.8383 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.752
# Epoch 295/300
#  - 1s - loss: 0.4455 - acc: 0.9318 - val_loss: 11.8681 - val_acc: 0.7136
#
# Balanced Accuracy - val: 0.732
# Epoch 296/300
#  - 1s - loss: 0.4700 - acc: 0.9284 - val_loss: 11.0948 - val_acc: 0.7294
#
# Balanced Accuracy - val: 0.743
# Epoch 297/300
#  - 1s - loss: 0.4930 - acc: 0.9263 - val_loss: 11.1099 - val_acc: 0.7028
#
# Balanced Accuracy - val: 0.724
# Epoch 298/300
#  - 1s - loss: 0.4663 - acc: 0.9321 - val_loss: 11.1938 - val_acc: 0.7258
#
# Balanced Accuracy - val: 0.717
# Epoch 299/300
#  - 1s - loss: 0.4834 - acc: 0.9259 - val_loss: 10.3562 - val_acc: 0.7186
#
# Balanced Accuracy - val: 0.737
# Epoch 300/300
#  - 1s - loss: 0.4586 - acc: 0.9299 - val_loss: 10.8243 - val_acc: 0.7394
#
# Balanced Accuracy - val: 0.751

# %%
print(history.history["acc"][-1])

# TRAIN SET
preds = model2.predict(X_train)

# decode one-hot to single labels
preds = [ np.argmax(pred, axis = 0) for pred in preds ]
labels = [ np.argmax(label, axis = 0) for label in y_train_one_hot ]

# Compute confusion matrix
cnf_matrix2 = confusion_matrix(labels, preds)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix2, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                      title='Normalized confusion matrix - Train set - MLP on Raw Data')

# TEST SET
preds = model2.predict(X_test)

# decode one-hot to single labels
preds = [ np.argmax(pred, axis = 0) for pred in preds ]
labels = [ np.argmax(label, axis = 0) for label in y_test_one_hot ]

# Compute confusion matrix
cnf_matrix2 = confusion_matrix(labels, preds)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix2, classes=["non-frail", "pre-frail", "frail"], normalize=True,
                      title='Normalized confusion matrix - Test set - MLP on Raw Data')

plt.show()
# Out:
# 0.854071031607
